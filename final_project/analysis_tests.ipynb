# %% [markdown]
# Needed:
# summary statistics are probably worth doing, but do something more than just summary statistics.
# At least two of the analyses should generate graphable data.
# At least one of the analyses should take a parameter. (e.g. the k in k-nearest neighbors)
#
#
# Plan:
# RUCC - classification of county
# predict #of beds, providers, operating rooms, ER(?) based on POS Q4s from 2013-2023 based on rural vs metro (generate graphs)
# clustering of distance to ER, urgent care, and medsurge ICU in SDOH
# summary statisticss of SDOH (standardized)
#
# Questions:
# is it okay to use the different datasets
# how do we account for large counties or population sizes
# how are we going to validate (could i tkae in a county and google that distance to hospital etc)
#
# Still Need to Do:
# Check for summary statistics/missing values/outliers
#     Summary Stats: distribution of classifications in country - can you do summary statistics of this; Per rural vs metro mean, median etc each year?; mean median of maximum distances per classification
# Preprocessing
# Validate and run analyses

# %%
import requests
import pandas as pd

# %%
# import api 

data_25q2 = (requests.get(f"https://data.cms.gov/data-api/v1/dataset/8ba0f9b4-9493-4aa0-9f82-44ea9468d1b5/data", headers={"User-Agent": "MyScript"}).json())

# %%
df_25q2 = pd.DataFrame(data_25q2)
#df_25q2 = df_25q2[["SSA_CNTY_CD","PRVDR_CTGRY_SBTYP_CD", "STATE_CD","CBSA_URBN_RRL_IND", "AFLTD_PRVDR_CNT", "BED_CNT", "TOT_OFSITE_EMER_DEPT_CNT","TOT_OFSITE_LTC_HOSP_CNT", "TOT_OFSITE_URGNT_CARE_CNTR_CNT", "OPRTG_ROOM_CNT"]]
df_25q2.head()
 #
# Out:
#   PRVDR_CTGRY_SBTYP_CD PRVDR_CTGRY_CD CHOW_CNT   CHOW_DT   CITY_NAME  \
# 0                   01             01        1                DOTHAN
# 1                   01             01        0            BRIDGEPORT
# 2                   01             01        0                  BOAZ
# 3                   01             01        1  20100701    FLORENCE
# 4                   01             01        0                   OPP
#
#   ACPTBL_POC_SW CMPLNC_STUS_CD SSA_CNTY_CD CROSS_REF_PROVIDER_NUMBER  \
# 0             N              B         340                    010163
# 1             N              A         350
# 2             Y              A         470
# 3             N              B         380
# 4             N              B         190
#
#   CRTFCTN_DT  ... OTHR_SRGRY_SW PAIN_SRGRY_SW PLSTC_SRGRY_SW FT_SRGRY_SW  \
# 0   20171005  ...
# 1   20010316  ...
# 2   20021003  ...
# 3   20190411  ...
# 4   20241212  ...
#
# ...

# %%
df_25q2[["AFLTD_PRVDR_CNT","BED_CNT","TOT_OFSITE_EMER_DEPT_CNT", "TOT_OFSITE_LTC_HOSP_CNT",  "TOT_OFSITE_URGNT_CARE_CNTR_CNT", "OPRTG_ROOM_CNT" ]].apply(pd.to_numeric, errors="coerce").sum()
# Out:
# AFLTD_PRVDR_CNT                      57.0
# BED_CNT                           35324.0
# TOT_OFSITE_EMER_DEPT_CNT             13.0
# TOT_OFSITE_LTC_HOSP_CNT               0.0
# TOT_OFSITE_URGNT_CARE_CNTR_CNT        0.0
# OPRTG_ROOM_CNT                      300.0
# dtype: float64

# %%
#2025 Q1 data and df

data_25q1 = (requests.get(f"https://data.cms.gov/data-api/v1/dataset/315bbdac-3888-43d9-9012-a9a2e29ca179/data", headers={"User-Agent": "MyScript"}).json())

# %%
df_25q1 = pd.DataFrame(data_25q1)
df_25q1 = df_25q1[["SSA_CNTY_CD","PRVDR_CTGRY_SBTYP_CD", "STATE_CD","CBSA_URBN_RRL_IND", "AFLTD_PRVDR_CNT", "BED_CNT", "TOT_OFSITE_EMER_DEPT_CNT","TOT_OFSITE_LTC_HOSP_CNT", "TOT_OFSITE_URGNT_CARE_CNTR_CNT", "OPRTG_ROOM_CNT"]]
df_25q1.head()
# Out:
#   SSA_CNTY_CD PRVDR_CTGRY_SBTYP_CD STATE_CD CBSA_URBN_RRL_IND AFLTD_PRVDR_CNT  \
# 0         340                   01       AL                 U               1
# 1         350                   01       AL                 R               0
# 2         470                   01       AL                 R               0
# 3         380                   01       AL                 U               0
# 4         190                   01       AL                 R               1
#
#   BED_CNT TOT_OFSITE_EMER_DEPT_CNT TOT_OFSITE_LTC_HOSP_CNT  \
# 0     420                        0                       0
# 1      64                        0                       0
# 2     240                        0                       0
# 3     338                        0                       0
# 4      99                        1                       0
#
#   TOT_OFSITE_URGNT_CARE_CNTR_CNT OPRTG_ROOM_CNT
# 0                              0             23
# ...

# %%
df_25q1[["AFLTD_PRVDR_CNT","BED_CNT","TOT_OFSITE_EMER_DEPT_CNT", "TOT_OFSITE_LTC_HOSP_CNT",  "TOT_OFSITE_URGNT_CARE_CNTR_CNT", "OPRTG_ROOM_CNT" ]].apply(pd.to_numeric, errors="coerce").sum()
# Out:
# AFLTD_PRVDR_CNT                      53.0
# BED_CNT                           35288.0
# TOT_OFSITE_EMER_DEPT_CNT             13.0
# TOT_OFSITE_LTC_HOSP_CNT               0.0
# TOT_OFSITE_URGNT_CARE_CNTR_CNT        0.0
# OPRTG_ROOM_CNT                      298.0
# dtype: float64

# %%
#2024 Q4 data and df

data_24q4 = (requests.get(f"https://data.cms.gov/data-api/v1/dataset/8143cbc7-484f-438b-9dfa-2e81d5d6a1ed/data", headers={"User-Agent": "MyScript"}).json())

# %%
df_24q4 = pd.DataFrame(data_24q4)
df_24q4 = df_24q4[["SSA_CNTY_CD","PRVDR_CTGRY_SBTYP_CD", "STATE_CD","CBSA_URBN_RRL_IND", "AFLTD_PRVDR_CNT", "BED_CNT", "TOT_OFSITE_EMER_DEPT_CNT","TOT_OFSITE_LTC_HOSP_CNT", "TOT_OFSITE_URGNT_CARE_CNTR_CNT", "OPRTG_ROOM_CNT"]]
df_24q4.head()
# Out:
#   SSA_CNTY_CD PRVDR_CTGRY_SBTYP_CD STATE_CD CBSA_URBN_RRL_IND AFLTD_PRVDR_CNT  \
# 0         340                   01       AL                 U               1
# 1         350                   01       AL                 R               0
# 2         470                   01       AL                 R               0
# 3         380                   01       AL                 U               0
# 4         190                   01       AL                 R               1
#
#   BED_CNT TOT_OFSITE_EMER_DEPT_CNT TOT_OFSITE_LTC_HOSP_CNT  \
# 0     420                        0                       0
# 1      64                        0                       0
# 2     240                        0                       0
# 3     338                        0                       0
# 4      99                        1                       0
#
#   TOT_OFSITE_URGNT_CARE_CNTR_CNT OPRTG_ROOM_CNT
# 0                              0             23
# ...

# %%
df_24q4[["AFLTD_PRVDR_CNT","BED_CNT","TOT_OFSITE_EMER_DEPT_CNT", "TOT_OFSITE_LTC_HOSP_CNT",  "TOT_OFSITE_URGNT_CARE_CNTR_CNT", "OPRTG_ROOM_CNT" ]].apply(pd.to_numeric, errors="coerce").sum()
# Out:
# AFLTD_PRVDR_CNT                      50.0
# BED_CNT                           35353.0
# TOT_OFSITE_EMER_DEPT_CNT             13.0
# TOT_OFSITE_LTC_HOSP_CNT               0.0
# TOT_OFSITE_URGNT_CARE_CNTR_CNT        0.0
# OPRTG_ROOM_CNT                      296.0
# dtype: float64

# %%
#2024 Q3 data and df

data_24q3 = (requests.get(f"https://data.cms.gov/data-api/v1/dataset/6b6a53a6-0020-4895-bdfe-c5a9f1733734/data", headers={"User-Agent": "MyScript"}).json())

# %%
df_24q3 = pd.DataFrame(data_24q3)
df_24q3 = df_24q3[["SSA_CNTY_CD","PRVDR_CTGRY_SBTYP_CD", "STATE_CD","CBSA_URBN_RRL_IND", "AFLTD_PRVDR_CNT", "BED_CNT", "TOT_OFSITE_EMER_DEPT_CNT","TOT_OFSITE_LTC_HOSP_CNT", "TOT_OFSITE_URGNT_CARE_CNTR_CNT", "OPRTG_ROOM_CNT"]]
df_24q3.head()
# Out:
#   SSA_CNTY_CD PRVDR_CTGRY_SBTYP_CD STATE_CD CBSA_URBN_RRL_IND AFLTD_PRVDR_CNT  \
# 0         340                   01       AL                 U               1
# 1         350                   01       AL                 R               0
# 2         470                   01       AL                 R               0
# 3         380                   01       AL                 U               0
# 4         190                   01       AL                 R               1
#
#   BED_CNT TOT_OFSITE_EMER_DEPT_CNT TOT_OFSITE_LTC_HOSP_CNT  \
# 0     420                        0                       0
# 1      64                        0                       0
# 2     240                        0                       0
# 3     338                        0                       0
# 4      99                        1                       0
#
#   TOT_OFSITE_URGNT_CARE_CNTR_CNT OPRTG_ROOM_CNT
# 0                              0             23
# ...

# %%
df_24q3[["AFLTD_PRVDR_CNT","BED_CNT","TOT_OFSITE_EMER_DEPT_CNT", "TOT_OFSITE_LTC_HOSP_CNT",  "TOT_OFSITE_URGNT_CARE_CNTR_CNT", "OPRTG_ROOM_CNT" ]].apply(pd.to_numeric, errors="coerce").sum()
# Out:
# AFLTD_PRVDR_CNT                      50.0
# BED_CNT                           35352.0
# TOT_OFSITE_EMER_DEPT_CNT             13.0
# TOT_OFSITE_LTC_HOSP_CNT               0.0
# TOT_OFSITE_URGNT_CARE_CNTR_CNT        0.0
# OPRTG_ROOM_CNT                      292.0
# dtype: float64

# %%
#2024 Q2 data and df

data_24q2 = (requests.get(f"https://data.cms.gov/data-api/v1/dataset/b3a134d0-6399-4809-9458-f02f3560e85a/data", headers={"User-Agent": "MyScript"}).json())

# %%
df_24q2 = pd.DataFrame(data_24q2)
df_24q2 = df_24q2[["SSA_CNTY_CD","PRVDR_CTGRY_SBTYP_CD", "STATE_CD","CBSA_URBN_RRL_IND", "AFLTD_PRVDR_CNT", "BED_CNT", "TOT_OFSITE_EMER_DEPT_CNT","TOT_OFSITE_LTC_HOSP_CNT", "TOT_OFSITE_URGNT_CARE_CNTR_CNT", "OPRTG_ROOM_CNT"]]
df_24q2.head()
# Out:
#   SSA_CNTY_CD PRVDR_CTGRY_SBTYP_CD STATE_CD CBSA_URBN_RRL_IND AFLTD_PRVDR_CNT  \
# 0         340                   01       AL                 U               1
# 1         350                   01       AL                 R               0
# 2         470                   01       AL                 R               0
# 3         380                   01       AL                 U               0
# 4         190                   01       AL                 R               1
#
#   BED_CNT TOT_OFSITE_EMER_DEPT_CNT TOT_OFSITE_LTC_HOSP_CNT  \
# 0     420                        0                       0
# 1      64                        0                       0
# 2     240                        0                       0
# 3     338                        0                       0
# 4      99                        1                       0
#
#   TOT_OFSITE_URGNT_CARE_CNTR_CNT OPRTG_ROOM_CNT
# 0                              0             23
# ...

# %%
df_24q2[["AFLTD_PRVDR_CNT","BED_CNT","TOT_OFSITE_EMER_DEPT_CNT", "TOT_OFSITE_LTC_HOSP_CNT",  "TOT_OFSITE_URGNT_CARE_CNTR_CNT", "OPRTG_ROOM_CNT" ]].apply(pd.to_numeric, errors="coerce").sum()
# Out:
# AFLTD_PRVDR_CNT                      49.0
# BED_CNT                           35365.0
# TOT_OFSITE_EMER_DEPT_CNT             13.0
# TOT_OFSITE_LTC_HOSP_CNT               0.0
# TOT_OFSITE_URGNT_CARE_CNTR_CNT        0.0
# OPRTG_ROOM_CNT                      292.0
# dtype: float64

# %%
#2024 Q1 data and df

data_24q1= (requests.get(f"https://data.cms.gov/data-api/v1/dataset/1a4586e7-6ea8-427b-9eca-2aaf25f2fd12/data", headers={"User-Agent": "MyScript"}).json())

# %%
df_24q1 = pd.DataFrame(data_24q1)
df_24q1 = df_24q1[["SSA_CNTY_CD","PRVDR_CTGRY_SBTYP_CD", "STATE_CD","CBSA_URBN_RRL_IND", "AFLTD_PRVDR_CNT", "BED_CNT", "TOT_OFSITE_EMER_DEPT_CNT","TOT_OFSITE_LTC_HOSP_CNT", "TOT_OFSITE_URGNT_CARE_CNTR_CNT", "OPRTG_ROOM_CNT"]]
df_24q1.head()
# Out:
#   SSA_CNTY_CD PRVDR_CTGRY_SBTYP_CD STATE_CD CBSA_URBN_RRL_IND AFLTD_PRVDR_CNT  \
# 0         340                   01       AL                 U               1
# 1         350                   01       AL                 R               0
# 2         470                   01       AL                 R               0
# 3         380                   01       AL                 U               0
# 4         190                   01       AL                 R               1
#
#   BED_CNT TOT_OFSITE_EMER_DEPT_CNT TOT_OFSITE_LTC_HOSP_CNT  \
# 0     420                        0                       0
# 1      64                        0                       0
# 2     240                        0                       0
# 3     338                        0                       0
# 4      99                        1                       0
#
#   TOT_OFSITE_URGNT_CARE_CNTR_CNT OPRTG_ROOM_CNT
# 0                              0             23
# ...

# %%
df_24q1[["AFLTD_PRVDR_CNT","BED_CNT","TOT_OFSITE_EMER_DEPT_CNT", "TOT_OFSITE_LTC_HOSP_CNT",  "TOT_OFSITE_URGNT_CARE_CNTR_CNT", "OPRTG_ROOM_CNT" ]].apply(pd.to_numeric, errors="coerce").sum()
# Out:
# AFLTD_PRVDR_CNT                      49.0
# BED_CNT                           35309.0
# TOT_OFSITE_EMER_DEPT_CNT             13.0
# TOT_OFSITE_LTC_HOSP_CNT               0.0
# TOT_OFSITE_URGNT_CARE_CNTR_CNT        0.0
# OPRTG_ROOM_CNT                      292.0
# dtype: float64

# %%
len(df_25q2)
# Out:
# 1000

# %%
print(df_25q2.columns.tolist())
# Out:
# ['PRVDR_CTGRY_SBTYP_CD', 'PRVDR_CTGRY_CD', 'CHOW_CNT', 'CHOW_DT', 'CITY_NAME', 'ACPTBL_POC_SW', 'CMPLNC_STUS_CD', 'SSA_CNTY_CD', 'CROSS_REF_PROVIDER_NUMBER', 'CRTFCTN_DT', 'ELGBLTY_SW', 'FAC_NAME', 'INTRMDRY_CARR_CD', 'MDCD_VNDR_NUM', 'ORGNL_PRTCPTN_DT', 'CHOW_PRIOR_DT', 'INTRMDRY_CARR_PRIOR_CD', 'PRVDR_NUM', 'RGN_CD', 'SKLTN_REC_SW', 'STATE_CD', 'SSA_STATE_CD', 'STATE_RGN_CD', 'ST_ADR', 'PHNE_NUM', 'PGM_TRMNTN_CD', 'TRMNTN_EXPRTN_DT', 'CRTFCTN_ACTN_TYPE_CD', 'GNRL_CNTL_TYPE_CD', 'ZIP_CD', 'FIPS_STATE_CD', 'FIPS_CNTY_CD', 'CBSA_URBN_RRL_IND', 'CBSA_CD', 'ACRDTN_EFCTV_DT', 'ACRDTN_EXPRTN_DT', 'ACRDTN_TYPE_CD', 'TOT_AFLTD_AMBLNC_SRVC_CNT', 'TOT_AFLTD_ASC_CNT', 'TOT_COLCTD_HOSP_CNT', 'TOT_AFLTD_ESRD_CNT', 'TOT_AFLTD_FQHC_CNT', 'TOT_AFLTD_HHA_CNT', 'TOT_AFLTD_HOSPC_CNT', 'TOT_AFLTD_OPO_CNT', 'TOT_AFLTD_PRTF_CNT', 'TOT_AFLTD_RHC_CNT', 'TOT_AFLTD_SNF_CNT', 'AFLTD_PRVDR_CNT', 'RSDNT_PGM_ALPTHC_SW', 'RSDNT_PGM_DNTL_SW', 'RSDNT_PGM_OSTPTHC_SW', 'RSDNT_PGM_OTHR_SW', 'RSDNT_PGM_PDTRC_SW', 'LAB_
# ...

# %% [markdown]
# Clustering of SDOH 2020 vs 2013
#
# How can I validate this?
