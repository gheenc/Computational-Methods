# %%
import pandas as pd
import numpy as np
import pickle

# %%
# import wanted 2020 data and columns
data_2020 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2020',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2020.head()
# Out:
#    YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2020  Alabama  Autauga County  South         55639.0
# 1  2020  Alabama  Baldwin County  South        218289.0
# 2  2020  Alabama  Barbour County  South         25026.0
# 3  2020  Alabama     Bibb County  South         22374.0
# 4  2020  Alabama   Blount County  South         57755.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54929.0                  2.0                2.25
# 1               216518.0                  3.0                6.01
# 2                24792.0                  6.0                5.58
# 3                22073.0                  1.0                8.44
# 4                57164.0                  1.0               10.56
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.29            17.88  ...                       5.36
# 1              6.44            13.43  ...                       7.52
# 2              8.56            22.72  ...                       8.56
# 3              8.34            15.53  ...                      21.31
# 4              9.68            17.69  ...                       9.82
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.95                   12.07                 14.68
# 1                     13.43                   25.37                 25.06
# 2                     22.72                   41.37                 41.32
# 3                     27.58                   26.40                 27.00
# 4                     19.89                   26.16                 27.23
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.36          0.02                       1.0
# 1                36.79          0.00                       3.0
# 2                46.80          0.00                       1.0
# 3                35.98          0.00                       0.0
# 4                34.04          0.00                       2.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.01              4.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.03              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
print(data_2020["STATE"].unique())

allowed_states = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
 'Connecticut', 'Delaware', 'Florida', 'Georgia',
 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky',
 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
 'Mississippi', 'Missouri','Montana', 'Nebraska', 'Nevada', 'New Hampshire',
 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota',
 'Ohio', 'Oklahoma','Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia',
 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']  

data_2020 = data_2020[data_2020["STATE"].isin(allowed_states)]
print(data_2020["STATE"].unique())

print(len(data_2020["STATE"].unique()))
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'District of Columbia' 'Florida' 'Georgia'
#  'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas' 'Kentucky'
#  'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan' 'Minnesota'
#  'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada' 'New Hampshire'
#  'New Jersey' 'New Mexico' 'New York' 'North Carolina' 'North Dakota'
#  'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania' 'Rhode Island' 'South Carolina'
#  'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virginia'
#  'Washington' 'West Virginia' 'Wisconsin' 'Wyoming' 'American Samoa'
#  'Guam' 'Northern Mariana Islands' 'Puerto Rico' 'US Virgin Islands']
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50

# %%
# Count how many missing values exist before filling
missing_count = data_2020.isna().sum().sum()

# get location of each missing value
missing_locations = data_2020.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2020.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2020.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")
# Out:
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 72, column 'AHRF_USDA_RUCC_2013'
# Missing value at row 73, column 'AHRF_USDA_RUCC_2013'
# Missing value at row 94, column 'ACS_TOT_POP_WT'
# Missing value at row 94, column 'ACS_TOT_POP_US_ABOVE1'
# Missing value at row 94, column 'POS_MEDIAN_DIST_ED'
# Missing value at row 94, column 'POS_MEAN_DIST_ED'
# Missing value at row 94, column 'POS_MAX_DIST_ED'
# Missing value at row 94, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 94, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 94, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 94, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 94, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 94, column 'POS_MAX_DIST_TRAUMA'
# Filled 19 missing values with 'NA'.

# %%
# find what had missing data 
print(data_2020.iloc[68]["STATE"])
print(data_2020.iloc[68]["COUNTY"])
print(data_2020.iloc[94]["STATE"])
print(data_2020.iloc[94]["COUNTY"])
print(data_2020.iloc[72]["STATE"])
print(data_2020.iloc[72]["COUNTY"])
print(data_2020.iloc[73]["STATE"])
print(data_2020.iloc[73]["COUNTY"])
# Out:
# Alaska
# Aleutians West Census Area
# Alaska
# Valdez-Cordova Census Area
# Alaska
# Chugach Census Area
# Alaska
# Copper River Census Area

# %%
print(data_2020.iloc[72])
print(data_2020.iloc[73])
# Out:
# YEAR                                          2020
# STATE                                       Alaska
# COUNTY                         Chugach Census Area
# REGION                                        West
# ACS_TOT_POP_WT                              6495.0
# ACS_TOT_POP_US_ABOVE1                       6453.0
# AHRF_USDA_RUCC_2013                            NaN
# POS_MEDIAN_DIST_ED                            3.44
# POS_MEAN_DIST_ED                              3.44
# POS_MAX_DIST_ED                               5.89
# POS_MEDIAN_DIST_MEDSURG_ICU                 114.39
# POS_MEAN_DIST_MEDSURG_ICU                   114.39
# POS_MAX_DIST_MEDSURG_ICU                    130.92
# POS_MEDIAN_DIST_TRAUMA                       24.45
# POS_MEAN_DIST_TRAUMA                         24.45
# POS_MAX_DIST_TRAUMA                          42.54
# POS_ASC_RATE                                   0.0
# POS_TOT_HOSP_MEDSURG_ICU                       0.0
# POS_HOSP_MEDSURG_ICU_RATE                      0.0
# POS_TOT_HOSP_ED                                4.0
# POS_HOSP_ED_RATE                              0.62
# Name: 72, dtype: object
# YEAR                                               2020
# STATE                                            Alaska
# COUNTY                         Copper River Census Area
# REGION                                             West
# ACS_TOT_POP_WT                                   2894.0
# ACS_TOT_POP_US_ABOVE1                            2835.0
# AHRF_USDA_RUCC_2013                                 NaN
# POS_MEDIAN_DIST_ED                                16.63
# POS_MEAN_DIST_ED                                  16.63
# POS_MAX_DIST_ED                                   16.63
# POS_MEDIAN_DIST_MEDSURG_ICU                      142.15
# POS_MEAN_DIST_MEDSURG_ICU                        142.15
# POS_MAX_DIST_MEDSURG_ICU                         142.15
# POS_MEDIAN_DIST_TRAUMA                            78.58
# POS_MEAN_DIST_TRAUMA                              78.58
# POS_MAX_DIST_TRAUMA                               78.58
# POS_ASC_RATE                                        0.0
# POS_TOT_HOSP_MEDSURG_ICU                            0.0
# POS_HOSP_MEDSURG_ICU_RATE                           0.0
# POS_TOT_HOSP_ED                                     1.0
# POS_HOSP_ED_RATE                                   0.35
# Name: 73, dtype: object

# %%
print(data_2020.iloc[94])
# Out:
# YEAR                                                 2020
# STATE                                              Alaska
# COUNTY                         Valdez-Cordova Census Area
# REGION                                               West
# ACS_TOT_POP_WT                                        NaN
# ACS_TOT_POP_US_ABOVE1                                 NaN
# AHRF_USDA_RUCC_2013                                   9.0
# POS_MEDIAN_DIST_ED                                    NaN
# POS_MEAN_DIST_ED                                      NaN
# POS_MAX_DIST_ED                                       NaN
# POS_MEDIAN_DIST_MEDSURG_ICU                           NaN
# POS_MEAN_DIST_MEDSURG_ICU                             NaN
# POS_MAX_DIST_MEDSURG_ICU                              NaN
# POS_MEDIAN_DIST_TRAUMA                                NaN
# POS_MEAN_DIST_TRAUMA                                  NaN
# POS_MAX_DIST_TRAUMA                                   NaN
# POS_ASC_RATE                                          0.0
# POS_TOT_HOSP_MEDSURG_ICU                              0.0
# POS_HOSP_MEDSURG_ICU_RATE                             0.0
# POS_TOT_HOSP_ED                                       0.0
# POS_HOSP_ED_RATE                                      0.0
# Name: 94, dtype: object

# %%
print(data_2020.iloc[68])
# Out:
# YEAR                                                 2020
# STATE                                              Alaska
# COUNTY                         Aleutians West Census Area
# REGION                                               West
# ACS_TOT_POP_WT                                     5708.0
# ACS_TOT_POP_US_ABOVE1                              5674.0
# AHRF_USDA_RUCC_2013                                   9.0
# POS_MEDIAN_DIST_ED                                 468.73
# POS_MEAN_DIST_ED                                   468.73
# POS_MAX_DIST_ED                                    468.73
# POS_MEDIAN_DIST_MEDSURG_ICU                           NaN
# POS_MEAN_DIST_MEDSURG_ICU                             NaN
# POS_MAX_DIST_MEDSURG_ICU                              NaN
# POS_MEDIAN_DIST_TRAUMA                                NaN
# POS_MEAN_DIST_TRAUMA                                  NaN
# POS_MAX_DIST_TRAUMA                                   NaN
# POS_ASC_RATE                                          0.0
# POS_TOT_HOSP_MEDSURG_ICU                              0.0
# POS_HOSP_MEDSURG_ICU_RATE                             0.0
# POS_TOT_HOSP_ED                                       0.0
# POS_HOSP_ED_RATE                                      0.0
# Name: 68, dtype: object

# %%
# repeat for 2019 data 
data_2019 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2019',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2019.head()
# Out:
#    YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2019  Alabama  Autauga County  South         55380.0
# 1  2019  Alabama  Baldwin County  South        212830.0
# 2  2019  Alabama  Barbour County  South         25361.0
# 3  2019  Alabama     Bibb County  South         22493.0
# 4  2019  Alabama   Blount County  South         57681.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54699.0                  2.0                2.20
# 1               210908.0                  3.0                6.21
# 2                25050.0                  6.0                5.89
# 3                22141.0                  1.0                9.24
# 4                57191.0                  1.0               10.46
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.33            18.07  ...                       5.40
# 1              6.51            18.61  ...                       7.50
# 2              8.58            22.69  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             10.22            17.79  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   26.28                 25.65
# 2                     22.69                   41.52                 41.27
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                36.06          0.00                       3.0
# 2                46.80          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       2.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.01              4.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.03              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2019 = data_2019[data_2019["STATE"].isin(allowed_states)]
print(data_2019["STATE"].unique())

print(len(data_2019["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2019.isna().sum().sum()

# get location of each missing value
missing_locations = data_2019.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2019.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2019.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print(data_2019.iloc[68]["STATE"])
print(data_2019.iloc[68]["COUNTY"])
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Filled 6 missing values with 'NA'.
# Alaska
# Aleutians West Census Area

# %%
# repeat for 2018 data 
data_2018 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2018',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2018.head()
# Out:
#      YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2018.0  Alabama  Autauga County  South         55200.0
# 1  2018.0  Alabama  Baldwin County  South        208107.0
# 2  2018.0  Alabama  Barbour County  South         25782.0
# 3  2018.0  Alabama     Bibb County  South         22527.0
# 4  2018.0  Alabama   Blount County  South         57645.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54509.0                  2.0                2.20
# 1               206023.0                  3.0                6.21
# 2                25469.0                  6.0                5.89
# 3                22112.0                  1.0                9.24
# 4                57144.0                  1.0               10.46
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.33            18.07  ...                       5.40
# 1              6.51            18.61  ...                       7.50
# 2              8.58            22.69  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             10.22            17.79  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   26.28                 25.65
# 2                     22.69                   41.52                 41.27
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                36.06          0.00                       3.0
# 2                46.80          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       2.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.01              4.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.03              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2018 = data_2018[data_2018["STATE"].isin(allowed_states)]
print(data_2018["STATE"].unique())

print(len(data_2018["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2018.isna().sum().sum()

# get location of each missing value
missing_locations = data_2018.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2018.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2018.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print(data_2018.iloc[68]["STATE"])
print(data_2018.iloc[68]["COUNTY"])
print(data_2018.iloc[1815]["STATE"])
print(data_2018.iloc[1815]["COUNTY"])
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 1815, column 'ACS_TOT_POP_US_ABOVE1'
# Filled 7 missing values with 'NA'.
# Alaska
# Aleutians West Census Area
# New Mexico
# Rio Arriba County

# %%
# repeat for 2017 data 

data_2017 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2017',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2017.head()
# Out:
#      YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2017.0  Alabama  Autauga County  South         55036.0
# 1  2017.0  Alabama  Baldwin County  South        203360.0
# 2  2017.0  Alabama  Barbour County  South         26201.0
# 3  2017.0  Alabama     Bibb County  South         22580.0
# 4  2017.0  Alabama   Blount County  South         57667.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54293.0                  2.0                2.20
# 1               201089.0                  3.0                7.62
# 2                25925.0                  6.0                5.89
# 3                22224.0                  1.0                9.24
# 4                57088.0                  1.0               10.46
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.33            18.07  ...                       5.40
# 1              7.49            18.61  ...                       7.50
# 2              8.58            22.69  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             10.22            17.79  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   26.28                 25.65
# 2                     22.69                   41.52                 41.27
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                36.06          0.00                       3.0
# 2                46.80          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       2.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.01              3.0              0.01
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.03              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2017 = data_2017[data_2017["STATE"].isin(allowed_states)]
print(data_2017["STATE"].unique())

print(len(data_2017["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2017.isna().sum().sum()

# get location of each missing value
missing_locations = data_2017.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2017.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2017.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print(data_2017.iloc[68]["STATE"])
print(data_2017.iloc[68]["COUNTY"])
print(data_2017.iloc[85]["STATE"])
print(data_2017.iloc[85]["COUNTY"])
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 85, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 85, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 85, column 'POS_MAX_DIST_TRAUMA'
# Filled 9 missing values with 'NA'.
# Alaska
# Aleutians West Census Area
# Alaska
# North Slope Borough

# %%
# repeat for 2016 data 

data_2016 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2016',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2016.head()
# Out:
#      YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2016.0  Alabama  Autauga County  South         55049.0
# 1  2016.0  Alabama  Baldwin County  South        199510.0
# 2  2016.0  Alabama  Barbour County  South         26614.0
# 3  2016.0  Alabama     Bibb County  South         22572.0
# 4  2016.0  Alabama   Blount County  South         57704.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54311.0                  2.0                2.20
# 1               197124.0                  3.0                7.62
# 2                26332.0                  6.0                5.89
# 3                22349.0                  1.0                9.24
# 4                57199.0                  1.0               10.46
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.33            18.07  ...                       5.40
# 1              7.49            18.61  ...                       7.50
# 2              8.58            22.69  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             10.22            17.79  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   26.28                 25.65
# 2                     22.69                   43.95                 45.47
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                36.06          0.01                       3.0
# 2                53.56          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       2.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.02              3.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.03              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2016 = data_2016[data_2016["STATE"].isin(allowed_states)]
print(data_2016["STATE"].unique())

print(len(data_2016["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2016.isna().sum().sum()

# get location of each missing value
missing_locations = data_2016.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2016.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2016.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print((data_2016.iloc[68]["STATE"]), (data_2016.iloc[68]["COUNTY"]))
print((data_2016.iloc[85]["STATE"]), (data_2016.iloc[85]["COUNTY"]))
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 85, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 85, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 85, column 'POS_MAX_DIST_TRAUMA'
# Filled 9 missing values with 'NA'.
# Alaska Aleutians West Census Area
# Alaska North Slope Borough

# %%
# repeat for 2015 data 

data_2015 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2015',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2015.head()
# Out:
#    YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2015  Alabama  Autauga County  South         55221.0
# 1  2015  Alabama  Baldwin County  South        195121.0
# 2  2015  Alabama  Barbour County  South         26932.0
# 3  2015  Alabama     Bibb County  South         22604.0
# 4  2015  Alabama   Blount County  South         57710.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54662.0                  2.0                2.20
# 1               192790.0                  3.0                7.62
# 2                26692.0                  6.0                5.89
# 3                22359.0                  1.0                9.24
# 4                57157.0                  1.0               10.46
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.33            18.07  ...                       5.40
# 1              7.49            18.61  ...                       7.50
# 2              8.58            22.69  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             10.22            17.79  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   26.28                 25.65
# 2                     22.69                   43.95                 45.47
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                36.06          0.01                       3.0
# 2                53.56          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       2.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.02              3.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.03              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2015 = data_2015[data_2015["STATE"].isin(allowed_states)]
print(data_2015["STATE"].unique())

print(len(data_2015["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2015.isna().sum().sum()

# get location of each missing value
missing_locations = data_2015.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2015.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2015.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print((data_2015.iloc[67]["STATE"]), (data_2015.iloc[67]["COUNTY"]))
print((data_2015.iloc[68]["STATE"]), (data_2016.iloc[68]["COUNTY"]))
print((data_2015.iloc[84]["STATE"]), (data_2016.iloc[84]["COUNTY"]))
print((data_2015.iloc[85]["STATE"]), (data_2016.iloc[85]["COUNTY"]))
print((data_2015.iloc[86]["STATE"]), (data_2016.iloc[86]["COUNTY"]))
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 67, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 84, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 84, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 84, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 85, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 85, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 85, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 86, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 86, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 86, column 'POS_MAX_DIST_TRAUMA'
# Filled 18 missing values with 'NA'.
# Alaska Aleutians East Borough
# Alaska Aleutians West Census Area
# Alaska Nome Census Area
# Alaska North Slope Borough
# Alaska Northwest Arctic Borough

# %%
# repeat for 2014 data 

data_2014 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2014',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2014.head()
# Out:
#      YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2014.0  Alabama  Autauga County  South         55136.0
# 1  2014.0  Alabama  Baldwin County  South        191205.0
# 2  2014.0  Alabama  Barbour County  South         27119.0
# 3  2014.0  Alabama     Bibb County  South         22653.0
# 4  2014.0  Alabama   Blount County  South         57645.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54712.0                  2.0                2.20
# 1               188664.0                  3.0                7.62
# 2                26834.0                  6.0                5.89
# 3                22446.0                  1.0                9.24
# 4                57022.0                  1.0               10.46
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.33            18.07  ...                       5.40
# 1              7.49            18.61  ...                       7.50
# 2              8.58            22.69  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             10.22            17.79  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   26.28                 25.65
# 2                     22.69                   43.95                 45.47
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                36.06          0.01                       3.0
# 2                53.56          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       1.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.02              3.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.02              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2014 = data_2014[data_2014["STATE"].isin(allowed_states)]
print(data_2014["STATE"].unique())

print(len(data_2014["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2014.isna().sum().sum()

# get location of each missing value
missing_locations = data_2014.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2014.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2014.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print((data_2014.iloc[67]["STATE"]), (data_2014.iloc[67]["COUNTY"]))
print((data_2014.iloc[68]["STATE"]), (data_2014.iloc[68]["COUNTY"]))
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 67, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Filled 9 missing values with 'NA'.
# Alaska Aleutians East Borough
# Alaska Aleutians West Census Area

# %%
# repeat for 2013 data 

data_2013 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2013',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2013.head()
# Out:
#    YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2013  Alabama  Autauga County  South         54907.0
# 1  2013  Alabama  Baldwin County  South        187114.0
# 2  2013  Alabama  Barbour County  South         27321.0
# 3  2013  Alabama     Bibb County  South         22754.0
# 4  2013  Alabama   Blount County  South         57623.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54567.0                  2.0                2.20
# 1               184905.0                  3.0                7.62
# 2                27021.0                  6.0                5.89
# 3                22557.0                  1.0                9.24
# 4                56983.0                  1.0               10.46
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.33            18.07  ...                       5.40
# 1              7.49            18.61  ...                       7.50
# 2              8.58            22.69  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             10.22            17.79  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   26.28                 25.65
# 2                     22.69                   43.95                 45.47
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                36.06          0.01                       3.0
# 2                53.56          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       1.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.02              3.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.02              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2013 = data_2013[data_2013["STATE"].isin(allowed_states)]
print(data_2013["STATE"].unique())

print(len(data_2013["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2013.isna().sum().sum()

# get location of each missing value
missing_locations = data_2013.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2013.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2013.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print((data_2013.iloc[67]["STATE"]), (data_2013.iloc[67]["COUNTY"]))
print((data_2013.iloc[68]["STATE"]), (data_2013.iloc[68]["COUNTY"]))
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 67, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Filled 9 missing values with 'NA'.
# Alaska Aleutians East Borough
# Alaska Aleutians West Census Area

# %%
# repeat for 2012 data 

data_2012 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2012',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2012.head()
# Out:
#    YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2012  Alabama  Autauga County  South         54590.0
# 1  2012  Alabama  Baldwin County  South        183226.0
# 2  2012  Alabama  Barbour County  South         27469.0
# 3  2012  Alabama     Bibb County  South         22769.0
# 4  2012  Alabama   Blount County  South         57466.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54197.0                  2.0                2.20
# 1               180928.0                  3.0                7.62
# 2                27113.0                  6.0                5.89
# 3                22570.0                  1.0                9.24
# 4                56897.0                  1.0               10.46
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.33            18.07  ...                       5.40
# 1              7.49            18.61  ...                       7.50
# 2              8.58            22.69  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             10.22            17.79  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   26.28                 25.65
# 2                     22.69                   43.95                 45.47
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                36.06          0.01                       3.0
# 2                53.56          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       1.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.02              3.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.02              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2012 = data_2012[data_2012["STATE"].isin(allowed_states)]
print(data_2012["STATE"].unique())

print(len(data_2012["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2012.isna().sum().sum()

# get location of each missing value
missing_locations = data_2012.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2012.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2012.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print((data_2012.iloc[67]["STATE"]), (data_2012.iloc[67]["COUNTY"]))
print((data_2012.iloc[68]["STATE"]), (data_2012.iloc[68]["COUNTY"]))
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 67, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 69, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 69, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 69, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 74, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 74, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 74, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 78, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 78, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 78, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 80, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 80, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 80, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 81, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 81, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 81, column 'POS_MAX_DIST_TRAUMA'
# Filled 24 missing values with 'NA'.
# Alaska Aleutians East Borough
# Alaska Aleutians West Census Area

# %%
# repeat for 2011 data 

data_2011 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2011',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2011.head()
# Out:
#    YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2011  Alabama  Autauga County  South         53944.0
# 1  2011  Alabama  Baldwin County  South        179523.0
# 2  2011  Alabama  Barbour County  South         27546.0
# 3  2011  Alabama     Bibb County  South         22746.0
# 4  2011  Alabama   Blount County  South         57140.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                53436.0                  2.0                2.20
# 1               177221.0                  3.0                7.62
# 2                27117.0                  6.0                5.89
# 3                22600.0                  1.0                9.24
# 4                56552.0                  1.0               10.46
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.33            18.07  ...                       5.40
# 1              7.49            18.61  ...                       7.50
# 2              8.58            22.69  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             10.22            17.79  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   20.95                 20.69
# 2                     22.69                   43.95                 47.74
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                35.46          0.01                       3.0
# 2                63.22          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       1.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.02              3.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.02              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2011 = data_2011[data_2011["STATE"].isin(allowed_states)]
print(data_2011["STATE"].unique())

print(len(data_2011["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2011.isna().sum().sum()

# get location of each missing value
missing_locations = data_2011.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2011.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2011.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print((data_2011.iloc[67]["STATE"]), (data_2011.iloc[67]["COUNTY"]))
print((data_2011.iloc[68]["STATE"]), (data_2011.iloc[68]["COUNTY"]))
print((data_2011.iloc[69]["STATE"]), (data_2011.iloc[69]["COUNTY"]))
print((data_2011.iloc[74]["STATE"]), (data_2011.iloc[74]["COUNTY"]))
print((data_2011.iloc[78]["STATE"]), (data_2011.iloc[78]["COUNTY"]))
print((data_2011.iloc[80]["STATE"]), (data_2011.iloc[80]["COUNTY"]))
print((data_2011.iloc[81]["STATE"]), (data_2011.iloc[81]["COUNTY"]))
print((data_2011.iloc[90]["STATE"]), (data_2011.iloc[90]["COUNTY"]))
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 67, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 69, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 69, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 69, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 74, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 74, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 74, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 78, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 78, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 78, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 80, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 80, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 80, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 81, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 81, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 81, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 90, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 90, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 90, column 'POS_MAX_DIST_TRAUMA'
# Filled 27 missing values with 'NA'.
# Alaska Aleutians East Borough
# Alaska Aleutians West Census Area
# Alaska Anchorage Municipality
# Alaska Fairbanks North Star Borough
# Alaska Kenai Peninsula Borough
# Alaska Kodiak Island Borough
# Alaska Lake and Peninsula Borough
# Alaska Southeast Fairbanks Census Area

# %%
# repeat for 2010 data 

data_2010 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2010',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2010.head()
# Out:
#    YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2010  Alabama  Autauga County  South         53155.0
# 1  2010  Alabama  Baldwin County  South        175791.0
# 2  2010  Alabama  Barbour County  South         27699.0
# 3  2010  Alabama     Bibb County  South         22610.0
# 4  2010  Alabama   Blount County  South         56692.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                52568.0                  2.0               13.19
# 1               173522.0                  3.0               10.68
# 2                27230.0                  6.0               23.10
# 3                22449.0                  1.0                9.24
# 4                56071.0                  1.0               19.97
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0             14.38            25.09  ...                       5.40
# 1             10.90            23.31  ...                       7.50
# 2             22.73            25.34  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             20.94            25.61  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   20.95                 20.69
# 2                     22.69                   43.95                 47.74
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                35.46          0.01                       3.0
# 2                63.22          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       1.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              0.0              0.00
# 1                       0.02              2.0              0.01
# 2                       0.04              0.0              0.00
# 3                       0.00              1.0              0.04
# 4                       0.02              0.0              0.00
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2010 = data_2010[data_2010["STATE"].isin(allowed_states)]
print(data_2010["STATE"].unique())

print(len(data_2010["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2010.isna().sum().sum()

# get location of each missing value
missing_locations = data_2010.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2010.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2010.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print((data_2010.iloc[67]["STATE"]), (data_2010.iloc[67]["COUNTY"]))
print((data_2010.iloc[68]["STATE"]), (data_2010.iloc[68]["COUNTY"]))
print((data_2010.iloc[69]["STATE"]), (data_2010.iloc[69]["COUNTY"]))
print((data_2010.iloc[74]["STATE"]), (data_2010.iloc[74]["COUNTY"]))
print((data_2010.iloc[78]["STATE"]), (data_2010.iloc[78]["COUNTY"]))
print((data_2010.iloc[80]["STATE"]), (data_2010.iloc[80]["COUNTY"]))
print((data_2010.iloc[81]["STATE"]), (data_2010.iloc[81]["COUNTY"]))
print((data_2010.iloc[90]["STATE"]), (data_2010.iloc[90]["COUNTY"]))
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 67, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEDIAN_DIST_ED'
# Missing value at row 68, column 'POS_MEAN_DIST_ED'
# Missing value at row 68, column 'POS_MAX_DIST_ED'
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 69, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 69, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 69, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 74, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 74, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 74, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 78, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 78, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 78, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 80, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 80, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 80, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 81, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 81, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 81, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 90, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 90, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 90, column 'POS_MAX_DIST_TRAUMA'
# Filled 30 missing values with 'NA'.
# Alaska Aleutians East Borough
# Alaska Aleutians West Census Area
# Alaska Anchorage Municipality
# Alaska Fairbanks North Star Borough
# Alaska Kenai Peninsula Borough
# Alaska Kodiak Island Borough
# Alaska Lake and Peninsula Borough
# Alaska Southeast Fairbanks Census Area

# %%
# summary stats of total number, maxiumum, mean, medium distance to er, trauma, and icu; total number of ambulatory surgery centers

# %%
# mak eone big dataframe 

df_cleaned = pd.concat([data_2020, data_2019, data_2018, data_2017, data_2016, data_2015, data_2014, data_2013], ignore_index=True)

df_cleaned['YEAR'] = df_cleaned['YEAR'].astype('Int64')
df_cleaned['AHRF_USDA_RUCC_2013'] = df_cleaned['AHRF_USDA_RUCC_2013'].astype('Int64')

df_cleaned.head()
# Out:
#    YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2020  Alabama  Autauga County  South         55639.0
# 1  2020  Alabama  Baldwin County  South        218289.0
# 2  2020  Alabama  Barbour County  South         25026.0
# 3  2020  Alabama     Bibb County  South         22374.0
# 4  2020  Alabama   Blount County  South         57755.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54929.0                    2                2.25
# 1               216518.0                    3                6.01
# 2                24792.0                    6                5.58
# 3                22073.0                    1                8.44
# 4                57164.0                    1               10.56
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.29            17.88  ...                       5.36
# 1              6.44            13.43  ...                       7.52
# 2              8.56            22.72  ...                       8.56
# 3              8.34            15.53  ...                      21.31
# 4              9.68            17.69  ...                       9.82
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.95                   12.07                 14.68
# 1                     13.43                   25.37                 25.06
# 2                     22.72                   41.37                 41.32
# 3                     27.58                   26.40                 27.00
# 4                     19.89                   26.16                 27.23
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.36          0.02                       1.0
# 1                36.79          0.00                       3.0
# 2                46.80          0.00                       1.0
# 3                35.98          0.00                       0.0
# 4                34.04          0.00                       2.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.01              4.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.03              1.0              0.02
#
# [5 rows x 21 columns]

# %%
df_cleaned[df_cleaned['AHRF_USDA_RUCC_2013'].isna()]
# Out:
#     YEAR   STATE                    COUNTY REGION  ACS_TOT_POP_WT  \
# 72  2020  Alaska       Chugach Census Area   West          6495.0
# 73  2020  Alaska  Copper River Census Area   West          2894.0
#
#     ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 72                 6453.0                 <NA>                3.44
# 73                 2835.0                 <NA>               16.63
#
#     POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 72              3.44             5.89  ...                     114.39
# 73             16.63            16.63  ...                     142.15
#
#     POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 72                    130.92                   24.45                 24.45
# 73                    142.15                   78.58                 78.58
#
#     POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 72                42.54           0.0                       0.0
# 73                78.58           0.0                       0.0
#
#     POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 72                        0.0              4.0              0.62
# 73                        0.0              1.0              0.35
#
# [2 rows x 21 columns]

# %%
df_cleaned['AHRF_USDA_RUCC_2013'].describe()
# Out:
# count     25129.0
# mean      5.00975
# std      2.707532
# min           1.0
# 25%           2.0
# 50%           6.0
# 75%           7.0
# max           9.0
# Name: AHRF_USDA_RUCC_2013, dtype: Float64

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 9999)

# %%
df_cleaned.describe()
# Out:
#               YEAR  ACS_TOT_POP_WT  ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  POS_MEAN_DIST_ED  POS_MAX_DIST_ED  POS_MEDIAN_DIST_MEDSURG_ICU  POS_MEAN_DIST_MEDSURG_ICU  POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# count      25131.0    2.513000e+04           2.512900e+04              25129.0        25130.000000      25130.000000     25130.000000                 25122.000000               25122.000000              25122.000000            25114.000000          25114.000000         25114.000000  25131.000000              25131.000000               25131.000000     25131.000000      25131.000000
# mean   2016.500139    1.014954e+05           1.003157e+05              5.00975            7.664434          8.155618        15.032981                    12.228878                  12.703859                 19.840563               23.162723             23.406801            31.103632      0.011494                  1.853647                   0.038264         2.612630          0.100354
# std       2.291516    3.256622e+05           3.217401e+05             2.707532           13.707003         13.419092        14.775390                    18.532922                  18.229941                 18.855607               23.527538             23.257161            23.997856      0.023152                  5.069786                   0.073053         5.005965          0.171490
# min         2013.0    6.600000e+01           6.500000e+01                  1.0            0.130000          0.130000         0.130000                     0.130000                   0.130000                  0.130000                0.130000              0.130000             0.130000      0.000000                  0.000000                   0.000000         0.000000          0.000000
# 25%         2014.5    1.097925e+04           1.086800e+04                  2.0            2.850000          4.000000         9.680000                     3.460000                   4.660000                 11.690000                7.090000              7.760000            17.930000      0.000000                  0.000000                   0.000000         1.000000          0.010000
# 50%         2017.0    2.573900e+04           2.545500e+04                  6.0            5.040000          5.670000        13.060000                     6.930000                   7.330000                 16.200000               19.460000             19.450000            26.870000      0.000000                  1.000000                   0.020000         2.000000          0.040000
# 75%         2019.0    6.742375e+04           6.680200e+04                  7.0            8.540000          8.510000        17.190000                    16.790000                  16.690000                 23.390000               31.900000             31.730000            39.167500      0.020000                  2.000000                   0.040000         3.000000          0.110000
# max         2020.0    1.010572e+07           9.988370e+06                  9.0          468.840000        468.840000       468.840000                   487.030000                 487.030000                487.030000              460.230000            460.230000           460.230000      0.430000                177.000000                   1.120000       147.000000          2.770000

# %%
df_cleaned[df_cleaned["YEAR"] == 2013].describe()
# Out:
#          YEAR  ACS_TOT_POP_WT  ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  \
# count  3142.0    3.142000e+03           3.142000e+03               3142.0
# mean   2013.0    9.895520e+04           9.776745e+04             5.008912
# std       0.0    3.164056e+05           3.124727e+05             2.707998
# min    2013.0    7.100000e+01           7.100000e+01                  1.0
# 25%    2013.0    1.105000e+04           1.096625e+04                  2.0
# 50%    2013.0    2.577800e+04           2.549050e+04                  6.0
# 75%    2013.0    6.692150e+04           6.619125e+04                  7.0
# max    2013.0    9.893481e+06           9.777020e+06                  9.0
#
#        POS_MEDIAN_DIST_ED  POS_MEAN_DIST_ED  POS_MAX_DIST_ED  \
# count         3142.000000       3142.000000      3142.000000
# mean             7.647721          8.140165        14.983759
# std             13.688965         13.400961        14.763260
# min              0.280000          0.280000         0.280000
# 25%              2.842500          3.990000         9.642500
# 50%              5.030000          5.660000        13.040000
# 75%              8.520000          8.500000        17.147500
# max            468.840000        468.840000       468.840000
#
#        POS_MEDIAN_DIST_MEDSURG_ICU  POS_MEAN_DIST_MEDSURG_ICU  \
# count                  3141.000000                3141.000000
# mean                     12.113072                  12.598835
# std                      18.402618                  18.110617
# min                       0.380000                   0.400000
# 25%                       3.430000                   4.640000
# 50%                       6.880000                   7.320000
# 75%                      16.510000                  16.470000
# max                     450.910000                 450.910000
#
#        POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# count               3141.000000             3140.000000           3140.000000
# mean                  19.709822               25.223048             25.453092
# std                   18.771046               25.303639             25.183332
# min                    0.400000                0.280000              0.280000
# 25%                   11.580000                8.295000              8.690000
# 50%                   16.100000               21.110000             21.075000
# 75%                   23.070000               34.442500             34.310000
# max                  450.910000              390.880000            390.880000
#
#        POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# count          3140.000000   3142.000000               3142.000000
# mean             33.099038      0.010863                  1.853915
# std              25.881271      0.022207                  5.044026
# min               0.280000      0.000000                  0.000000
# 25%              19.200000      0.000000                  0.000000
# 50%              28.060000      0.000000                  1.000000
# 75%              41.347500      0.020000                  2.000000
# max             390.880000      0.420000                174.000000
#
#        POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# count                3142.000000      3142.000000       3142.000000
# mean                    0.039249         2.608848          0.098546
# std                     0.075836         5.058973          0.166513
# min                     0.000000         0.000000          0.000000
# 25%                     0.000000         1.000000          0.010000
# 50%                     0.020000         2.000000          0.040000
# 75%                     0.040000         3.000000          0.110000
# max                     1.070000       146.000000          1.750000

# %%
df_cleaned[df_cleaned["YEAR"] == 2020].describe()
# Out:
#          YEAR  ACS_TOT_POP_WT  ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  \
# count  3143.0    3.142000e+03           3.142000e+03               3141.0
# mean   2020.0    1.037133e+05           1.025621e+05             5.009869
# std       0.0    3.319786e+05           3.282019e+05             2.707897
# min    2020.0    1.170000e+02           1.090000e+02                  1.0
# 25%    2020.0    1.090475e+04           1.076525e+04                  2.0
# 50%    2020.0    2.569750e+04           2.542300e+04                  6.0
# 75%    2020.0    6.799125e+04           6.722100e+04                  7.0
# max    2020.0    1.004068e+07           9.934933e+06                  9.0
#
#        POS_MEDIAN_DIST_ED  POS_MEAN_DIST_ED  POS_MAX_DIST_ED  \
# count         3142.000000       3142.000000      3142.000000
# mean             7.670999          8.167107        15.241814
# std             13.849934         13.556914        14.795877
# min              0.130000          0.130000         0.130000
# 25%              2.920000          4.040000         9.900000
# 50%              5.020000          5.670000        13.250000
# 75%              8.540000          8.557500        17.595000
# max            468.730000        468.730000       468.730000
#
#        POS_MEDIAN_DIST_MEDSURG_ICU  POS_MEAN_DIST_MEDSURG_ICU  \
# count                  3141.000000                3141.000000
# mean                     12.348777                  12.817931
# std                      18.855982                  18.560990
# min                       0.130000                   0.130000
# 25%                       3.520000                   4.720000
# 50%                       6.960000                   7.400000
# 75%                      16.860000                  16.910000
# max                     487.030000                 487.030000
#
#        POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# count               3141.000000             3141.000000           3141.000000
# mean                  20.181028               21.835100             22.081697
# std                   19.128694               22.611572             22.281632
# min                    0.130000                0.130000              0.130000
# 25%                   11.930000                6.620000              7.460000
# 50%                   16.550000               18.430000             18.490000
# 75%                   23.890000               30.000000             29.950000
# max                  487.030000              428.860000            428.860000
#
#        POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# count          3141.000000   3143.000000               3143.000000
# mean             30.022518      0.012246                  1.848871
# std              23.145195      0.024333                  5.067125
# min               0.130000      0.000000                  0.000000
# 25%              17.460000      0.000000                  0.000000
# 50%              26.140000      0.000000                  1.000000
# 75%              37.720000      0.020000                  2.000000
# max             428.860000      0.430000                173.000000
#
#        POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# count                3143.000000      3143.000000       3143.000000
# mean                    0.037617         2.613427          0.102319
# std                     0.071471         4.890634          0.175567
# min                     0.000000         0.000000          0.000000
# 25%                     0.000000         1.000000          0.010000
# 50%                     0.020000         2.000000          0.040000
# 75%                     0.040000         3.000000          0.120000
# max                     0.950000       121.000000          2.120000

# %%
df_cleaned.groupby('AHRF_USDA_RUCC_2013').describe()
# Out:
#                        YEAR                                                                  ACS_TOT_POP_WT                                                                                   ACS_TOT_POP_US_ABOVE1                                                                                  POS_MEDIAN_DIST_ED                                                           POS_MEAN_DIST_ED                                                            POS_MAX_DIST_ED                                                               POS_MEDIAN_DIST_MEDSURG_ICU                                                            POS_MEAN_DIST_MEDSURG_ICU                                                              POS_MAX_DIST_MEDSURG_ICU                                                              POS_MEDIAN_DIST_TRAUMA                                                               POS_MEAN_DIST_TRAUMA                                                               POS_MAX_DIST_TRAUMA                                                             POS_ASC_RATE                                                  POS_TOT_HOSP_MEDSURG_ICU                                                 POS_HOSP_MEDSURG_ICU_RATE                                                  POS_TOT_HOSP_ED                                                 POS_HOSP_ED_RATE
#                       count         mean       std     min      25%     50%      75%     max          count           mean            std      min       25%       50%        75%         max                 count           mean            std      min       25%       50%        75%        max              count       mean        std   min     25%   50%     75%     max            count       mean        std   min     25%   50%      75%     max           count       mean        std   min      25%     50%      75%     max                       count       mean        std   min    25%    50%      75%     max                     count       mean        std   min     25%     50%      75%     max                    count       mean        std   min     25%     50%      75%     max                  count       mean        std   min      25%     50%      75%     max                count       mean        std   min      25%     50%      75%     max               count       mean        std   min      25%     50%    75%     max        count      mean       std  min   25%   50%   75%   max                    count      mean        std  min  25%  50%  75%    max                     count      mean       std  min   25%   50%   75%   max           count      mean        std  min  25%  50%  75%    max            count      mean       std  min   25%   50%   75%   max
# AHRF_USDA_RUCC_2013
# 1                    3448.0       2016.5   2.29162  2013.0  2014.75  2016.5  2018.25  2020.0         3448.0  407628.599478  778196.052278   4782.0  43654.50  139930.5  494602.50  10105722.0                3448.0  402820.004350  768780.358072   4763.0  43148.50  138338.0  490101.25  9988370.0             3448.0   5.321099   4.033947  0.48  2.5100  4.07   6.560   25.15           3448.0   5.593962   3.793767  0.56  3.1400  4.70   6.6100   23.77          3448.0  12.944461   6.518656  0.70   9.3100  12.120  15.3400   71.65                      3448.0   6.129063   5.047032  0.53   2.64   4.33   7.5600   27.03                    3448.0   6.476494   4.902847  0.59   3.225   4.870   7.6700   26.69                   3448.0  14.041146   7.112502  1.80   9.740  12.930  16.5600   71.65                 3448.0  14.034643  10.050097  0.58   5.4075  12.110  20.2700   49.84               3448.0  14.333118   9.842023  0.58   6.2600  12.400  20.3925   48.79              3448.0  24.094791  11.573266  0.70  16.2300  22.990  30.14   90.46       3448.0  0.018016  0.022287  0.0  0.00  0.01  0.03  0.16                   3448.0  5.568445  12.396620  0.0  1.0  2.0  5.0  177.0                    3448.0  0.014513  0.014788  0.0  0.00  0.01  0.02  0.10          3448.0  6.135731  11.969724  0.0  1.0  2.0  6.0  147.0           3448.0  0.022628  0.030670  0.0  0.01  0.01  0.03  0.38
# 2                    3025.0  2016.498843  2.292171  2013.0   2014.0  2016.0   2018.0  2020.0         3025.0  179786.182810  198718.730336   1773.0  34835.00   93419.0  274184.00   1038476.0                3025.0  177669.448595  196271.279402   1768.0  34434.00   92460.0  271492.00  1028084.0             3025.0   5.887481   5.130577  1.00  2.6400  4.34   7.120   44.53           3025.0   6.552922   4.836329  1.00  3.7300  5.05   7.4500   44.53          3025.0  15.541174   7.300373  1.00  11.1300  14.170  17.6700   75.77                      3025.0   7.554826   6.824156  1.00   2.80   4.83   9.7900   51.52                    3025.0   8.223246   6.
# %%
df_cleaned[df_cleaned["YEAR"] == 2013] \
    .groupby("AHRF_USDA_RUCC_2013") \
    .describe()
# Out:
#                       YEAR                                                      ACS_TOT_POP_WT                                                                                  ACS_TOT_POP_US_ABOVE1                                                                                  POS_MEDIAN_DIST_ED                                                              POS_MEAN_DIST_ED                                                             POS_MAX_DIST_ED                                                               POS_MEDIAN_DIST_MEDSURG_ICU                                                               POS_MEAN_DIST_MEDSURG_ICU                                                               POS_MAX_DIST_MEDSURG_ICU                                                               POS_MEDIAN_DIST_TRAUMA                                                               POS_MEAN_DIST_TRAUMA                                                               POS_MAX_DIST_TRAUMA                                                               POS_ASC_RATE                                                  POS_TOT_HOSP_MEDSURG_ICU                                                 POS_HOSP_MEDSURG_ICU_RATE                                                   POS_TOT_HOSP_ED                                                 POS_HOSP_ED_RATE
#                      count    mean  std     min     25%     50%     75%     max          count           mean            std      min       25%       50%        75%        max                 count           mean            std      min       25%       50%        75%        max              count       mean        std   min     25%     50%      75%     max            count       mean        std   min     25%    50%      75%     max           count       mean        std   min      25%     50%      75%     max                       count       mean        std   min      25%     50%      75%     max                     count       mean        std   min      25%     50%      75%     max                    count       mean        std   min      25%     50%      75%     max                  count       mean        std   min      25%     50%      75%     max                count       mean        std   min      25%     50%      75%     max               count       mean        std   min      25%     50%      75%     max        count      mean       std  min   25%   50%   75%   max                    count      mean        std  min  25%  50%  75%    max                     count      mean       std   min   25%   50%   75%   max           count      mean        std  min  25%  50%  75%    max            count      mean       std  min   25%   50%     75%   max
# AHRF_USDA_RUCC_2013
# 1                    431.0  2013.0  0.0  2013.0  2013.0  2013.0  2013.0  2013.0          431.0  394344.324826  757753.405202   5062.0  42891.00  135940.0  471192.50  9893481.0                 431.0  389538.860789  748313.247905   5004.0  42389.50  134362.0  465595.50  9777020.0              431.0   5.341346   4.086026  0.48  2.5250   4.050   6.5000   24.76            431.0   5.610974   3.839618  0.56  3.1600  4.750   6.6000   23.52           431.0  12.926984   6.507980  0.70   9.3250  12.300  15.2000   64.43                       431.0   6.160928   5.098625  0.53   2.6400   4.390   7.5400   26.17                     431.0   6.507541   4.926931  0.59   3.2850   4.880   7.7600   26.69                    431.0  14.020835   7.114964  1.84   9.7400  12.900  16.5100   64.43                  431.0  14.311276  10.290987  0.79   5.4000  12.330  20.3000   49.84                431.0  14.600209  10.059166  0.95   6.2450  12.910  20.6100   48.64               431.0  24.423480  11.913536  1.84  16.5550  23.150  30.7500   90.46        431.0  0.016613  0.021123  0.0  0.00  0.01  0.03  0.14                    431.0  5.519722  12.348579  0.0  1.0  2.0  5.0  174.0                     431.0  0.014640  0.014653  0.00  0.01  0.01  0.02  0.09           431.0  6.132251  12.120275  0.0  1.0  2.0  6.0  146.0            431.0  0.023016  0.031648  0.0  0.01  0.01  0.0300  0.38
# 2                    379.0  2013.0  0.0  2013.0  2013.0  2013.0  2013.0  2013.0
# %%
df_cleaned[df_cleaned["YEAR"] == 2020] \
    .groupby("AHRF_USDA_RUCC_2013") \
    .describe()
# Out:
#                       YEAR                                                      ACS_TOT_POP_WT                                                                                   ACS_TOT_POP_US_ABOVE1                                                                                  POS_MEDIAN_DIST_ED                                                             POS_MEAN_DIST_ED                                                             POS_MAX_DIST_ED                                                               POS_MEDIAN_DIST_MEDSURG_ICU                                                               POS_MEAN_DIST_MEDSURG_ICU                                                               POS_MAX_DIST_MEDSURG_ICU                                                               POS_MEDIAN_DIST_TRAUMA                                                               POS_MEAN_DIST_TRAUMA                                                               POS_MAX_DIST_TRAUMA                                                               POS_ASC_RATE                                                  POS_TOT_HOSP_MEDSURG_ICU                                                 POS_HOSP_MEDSURG_ICU_RATE                                                    POS_TOT_HOSP_ED                                                 POS_HOSP_ED_RATE
#                      count    mean  std     min     25%     50%     75%     max          count           mean            std      min       25%       50%        75%         max                 count           mean            std      min       25%       50%        75%        max              count       mean        std   min     25%    50%      75%     max            count       mean        std   min     25%    50%      75%     max           count       mean        std   min      25%     50%      75%     max                       count       mean        std   min      25%     50%      75%     max                     count       mean        std   min      25%     50%      75%     max                    count       mean        std   min      25%     50%      75%     max                  count       mean        std   min      25%     50%      75%     max                count       mean        std   min      25%     50%      75%     max               count       mean        std   min      25%     50%      75%     max        count      mean       std  min   25%   50%   75%   max                    count      mean        std  min  25%  50%  75%    max                     count      mean       std  min   25%   50%     75%   max           count      mean        std  min  25%  50%  75%    max            count      mean       std  min     25%   50%     75%   max
# AHRF_USDA_RUCC_2013
# 1                    431.0  2020.0  0.0  2020.0  2020.0  2020.0  2020.0  2020.0          431.0  419009.129930  792037.974700   4782.0  44197.50  145839.0  504742.00  10040682.0                 431.0  414313.194896  783013.455584   4763.0  43827.00  144497.0  498456.50  9934933.0              431.0   5.378469   3.957856  0.49  2.5850  4.180   6.8400   25.15            431.0   5.618747   3.719664  0.57  3.1950  4.670   6.7500   23.77           431.0  13.134548   6.519602  0.89   9.4400  12.350  15.4950   71.65                       431.0   6.191323   5.005654  0.55   2.7350   4.450   7.8950   27.03                     431.0   6.489443   4.817856  0.60   3.3300   4.910   7.6100   26.19                    431.0  14.287633   7.159313  1.80   9.9500  13.050  16.7600   71.65                  431.0  13.858654   9.967632  0.81   5.4850  11.540  20.2150   47.18                431.0  14.179142   9.785974  0.94   6.1650  11.880  20.3050   48.79               431.0  24.115661  11.423275  1.80  16.3400  23.010  30.0100   88.45        431.0  0.019443  0.023707  0.0  0.00  0.01  0.03  0.16                    431.0  5.575406  12.396671  0.0  1.0  2.0  5.0  173.0                     431.0  0.014084  0.014707  0.0  0.00  0.01  0.0200  0.10           431.0  6.092807  11.649163  0.0  1.0  2.0  6.0  121.0            431.0  0.021787  0.028649  0.0  0.0100  0.01  0.0200  0.27
# 2                    378.0  2020.0  0.0  2020.0  2020.0  2020.0  2020.0  2020.0
# %%
for col in df_cleaned.columns:
    print(f"--- {col} ---")
    print(df_cleaned[col].describe())
    print()
# Out:
# --- YEAR ---
# count        25131.0
# mean     2016.500139
# std         2.291516
# min           2013.0
# 25%           2014.5
# 50%           2017.0
# 75%           2019.0
# max           2020.0
# Name: YEAR, dtype: Float64
#
# --- STATE ---
# count     25131
# unique       50
# top       Texas
# freq       2032
# Name: STATE, dtype: object
#
# --- COUNTY ---
# count                 25131
# unique                 1878
# top       Washington County
# freq                    248
# Name: COUNTY, dtype: object
#
# --- REGION ---
# count     25131
# unique        4
# top       South
# freq      11369
# Name: REGION, dtype: object
#
# --- ACS_TOT_POP_WT ---
# count    2.513000e+04
# mean     1.014954e+05
# std      3.256622e+05
# min      6.600000e+01
# 25%      1.097925e+04
# 50%      2.573900e+04
# 75%      6.742375e+04
# max      1.010572e+07
# Name: ACS_TOT_POP_WT, dtype: float64
#
# --- ACS_TOT_POP_US_ABOVE1 ---
# count    2.512900e+04
# mean     1.003157e+05
# std      3.217401e+05
# min      6.500000e+01
# 25%      1.086800e+04
# 50%      2.545500e+04
# 75%      6.680200e+04
# max      9.988370e+06
# Name: ACS_TOT_POP_US_ABOVE1, dtype: float64
#
# --- AHRF_USDA_RUCC_2013 ---
# count     25129.0
# mean      5.00975
# std      2.707532
# min           1.0
# 25%           2.0
# 50%           6.0
# 75%           7.0
# max           9.0
# Name: AHRF_USDA_RUCC_2013, dtype: Float64
#
# --- POS_MEDIAN_DIST_ED ---
# count    25130.000000
# mean         7.664434
# std         13.707003
# min          0.130000
# 25%          2.850000
# 50%          5.040000
# 75%          8.540000
# max        468.840000
# Name: POS_MEDIAN_DIST_ED, dtype: float64
#
# --- POS_MEAN_DIST_ED ---
# count    25130.000000
# mean         8.155618
# std         13.419092
# min          0.130000
# 25%          4.000000
# 50%          5.670000
# 75%          8.510000
# max        468.840000
# Name: POS_MEAN_DIST_ED, dtype: float64
#
# --- POS_MAX_DIST_ED ---
# count    25130.000000
# mean        15.032981
# std         14.775390
# min          0.130000
# 25%          9.680000
# 50%         13.060000
# 75%         17.190000
# max        468.840000
# Name: POS_MAX_DIST_ED, dtype: float64
#
# --- POS_MEDIAN_DIST_MEDSURG_ICU ---
# count    25122.000000
# mean        12.228878
# std         18.532922
# min          0.130000
# 25%          3.460000
# 50%          6.930000
# 75%         16.790000
# max        487.030000
# Name: POS_MEDIAN_DIST_MEDSURG_ICU, dtype: float64
#
# --- POS_MEAN_DIST_MEDSURG_ICU ---
# count    25122.000000
# mean        12.703859
# std         18.229941
# min          0.130000
# 25%          4.660000
# 50%          7.330000
# 75%         16.690000
# max        487.030000
# Name: POS_MEAN_DIST_MEDSURG_ICU, dtype: float64
#
# --- POS_MAX_DIST_MEDSURG_ICU ---
# count    25122.000000
# mean        19.840563
# std         18.855607
# min          0.130000
# 25%         11.690000
# 50%         16.200000
# 75%         23.390000
# max        487.030000
# Name: POS_MAX_DIST_MEDSURG_ICU, dtype: float64
#
# --- POS_MEDIAN_DIST_TRAUMA ---
# count    25114.000000
# mean        23.162723
# std         23.527538
# min          0.130000
# 25%          7.090000
# 50%         19.460000
# 75%         31.900000
# max        460.230000
# Name: POS_MEDIAN_DIST_TRAUMA, dtype: float64
#
# --- POS_MEAN_DIST_TRAUMA ---
# count    25114.000000
# mean        23.406801
# std         23.257161
# min          0.130000
# 25%          7.760000
# 50%         19.450000
# 75%         31.730000
# max        460.230000
# Name: POS_MEAN_DIST_TRAUMA, dtype: float64
#
# --- POS_MAX_DIST_TRAUMA ---
# count    25114.000000
# mean        31.103632
# std         23.997856
# min          0.130000
# 25%         17.930000
# 50%         26.870000
# 75%         39.167500
# max        460.230000
# Name: POS_MAX_DIST_TRAUMA, dtype: float64
#
# --- POS_ASC_RATE ---
# count    25131.000000
# mean         0.011494
# std          0.023152
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.020000
# max          0.430000
# Name: POS_ASC_RATE, dtype: float64
#
# --- POS_TOT_HOSP_MEDSURG_ICU ---
# count    25131.000000
# mean         1.853647
# std          5.069786
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max        177.000000
# Name: POS_TOT_HOSP_MEDSURG_ICU, dtype: float64
#
# --- POS_HOSP_MEDSURG_ICU_RATE ---
# count    25131.000000
# mean         0.038264
# std          0.073053
# min          0.000000
# 25%          0.000000
# 50%          0.020000
# 75%          0.040000
# max          1.120000
# Name: POS_HOSP_MEDSURG_ICU_RATE, dtype: float64
#
# --- POS_TOT_HOSP_ED ---
# count    25131.000000
# mean         2.612630
# std          5.005965
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max        147.000000
# Name: POS_TOT_HOSP_ED, dtype: float64
#
# --- POS_HOSP_ED_RATE ---
# count    25131.000000
# mean         0.100354
# std          0.171490
# min          0.000000
# 25%          0.010000
# 50%          0.040000
# 75%          0.110000
# max          2.770000
# Name: POS_HOSP_ED_RATE, dtype: float64

# %%
df_cleaned["REGION"].unique()
# Out:
# array(['South', 'West', 'Northeast', 'Midwest'], dtype=object)

# %%
south_states = df_cleaned[df_cleaned['REGION'] == 'South']['STATE'].unique()
print("South:", south_states)

west_states = df_cleaned[df_cleaned['REGION'] == 'West']['STATE'].unique()
print("West:", west_states)

northeast_states = df_cleaned[df_cleaned['REGION'] == 'Northeast']['STATE'].unique()
print("Northeast:", northeast_states)

midwest_states = df_cleaned[df_cleaned['REGION'] == 'Midwest']['STATE'].unique()
print("Midwest:", midwest_states)
# Out:
# South: ['Alabama' 'Arkansas' 'Delaware' 'Florida' 'Georgia' 'Kentucky'
#  'Louisiana' 'Maryland' 'Mississippi' 'North Carolina' 'Oklahoma'
#  'South Carolina' 'Tennessee' 'Texas' 'Virginia' 'West Virginia']
# West: ['Alaska' 'Arizona' 'California' 'Colorado' 'Hawaii' 'Idaho' 'Montana'
#  'Nevada' 'New Mexico' 'Oregon' 'Utah' 'Washington' 'Wyoming']
# Northeast: ['Connecticut' 'Maine' 'Massachusetts' 'New Hampshire' 'New Jersey'
#  'New York' 'Pennsylvania' 'Rhode Island' 'Vermont']
# Midwest: ['Illinois' 'Indiana' 'Iowa' 'Kansas' 'Michigan' 'Minnesota' 'Missouri'
#  'Nebraska' 'North Dakota' 'Ohio' 'South Dakota' 'Wisconsin']

# %%
df_cleaned.to_parquet("clean_data.parquet")
