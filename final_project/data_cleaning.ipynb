# %%
import pandas as pd
import numpy as np
import pickle

# %%
# import wanted 2020 data and columns
data_2020 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2020',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2020.head()
# Out:
#    YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2020  Alabama  Autauga County  South         55639.0
# 1  2020  Alabama  Baldwin County  South        218289.0
# 2  2020  Alabama  Barbour County  South         25026.0
# 3  2020  Alabama     Bibb County  South         22374.0
# 4  2020  Alabama   Blount County  South         57755.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54929.0                  2.0                2.25
# 1               216518.0                  3.0                6.01
# 2                24792.0                  6.0                5.58
# 3                22073.0                  1.0                8.44
# 4                57164.0                  1.0               10.56
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.29            17.88  ...                       5.36
# 1              6.44            13.43  ...                       7.52
# 2              8.56            22.72  ...                       8.56
# 3              8.34            15.53  ...                      21.31
# 4              9.68            17.69  ...                       9.82
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.95                   12.07                 14.68
# 1                     13.43                   25.37                 25.06
# 2                     22.72                   41.37                 41.32
# 3                     27.58                   26.40                 27.00
# 4                     19.89                   26.16                 27.23
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.36          0.02                       1.0
# 1                36.79          0.00                       3.0
# 2                46.80          0.00                       1.0
# 3                35.98          0.00                       0.0
# 4                34.04          0.00                       2.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.01              4.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.03              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
print(data_2020["STATE"].unique())

allowed_states = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
 'Connecticut', 'Delaware', 'Florida', 'Georgia',
 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky',
 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
 'Mississippi', 'Missouri','Montana', 'Nebraska', 'Nevada', 'New Hampshire',
 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota',
 'Ohio', 'Oklahoma','Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia',
 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']  

data_2020 = data_2020[data_2020["STATE"].isin(allowed_states)]
print(data_2020["STATE"].unique())

print(len(data_2020["STATE"].unique()))
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50

# %%
# Count how many missing values exist before filling
missing_count = data_2020.isna().sum().sum()

# get location of each missing value
missing_locations = data_2020.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2020.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2020.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")
# Out:
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 72, column 'AHRF_USDA_RUCC_2013'
# Missing value at row 73, column 'AHRF_USDA_RUCC_2013'
# Missing value at row 94, column 'ACS_TOT_POP_WT'
# Missing value at row 94, column 'ACS_TOT_POP_US_ABOVE1'
# Missing value at row 94, column 'POS_MEDIAN_DIST_ED'
# Missing value at row 94, column 'POS_MEAN_DIST_ED'
# Missing value at row 94, column 'POS_MAX_DIST_ED'
# Missing value at row 94, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 94, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 94, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 94, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 94, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 94, column 'POS_MAX_DIST_TRAUMA'
# Filled 19 missing values with 'NA'.

# %%
# find what had missing data 
print(data_2020.iloc[68]["STATE"])
print(data_2020.iloc[68]["COUNTY"])
print(data_2020.iloc[94]["STATE"])
print(data_2020.iloc[94]["COUNTY"])
# Out:
# Alaska
# Aleutians West Census Area
# Alaska
# Valdez-Cordova Census Area

# %%
# repeat for 2019 data 
data_2019 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2019',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2019.head()
# Out:
#    YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2019  Alabama  Autauga County  South         55380.0
# 1  2019  Alabama  Baldwin County  South        212830.0
# 2  2019  Alabama  Barbour County  South         25361.0
# 3  2019  Alabama     Bibb County  South         22493.0
# 4  2019  Alabama   Blount County  South         57681.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54699.0                  2.0                2.20
# 1               210908.0                  3.0                6.21
# 2                25050.0                  6.0                5.89
# 3                22141.0                  1.0                9.24
# 4                57191.0                  1.0               10.46
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.33            18.07  ...                       5.40
# 1              6.51            18.61  ...                       7.50
# 2              8.58            22.69  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             10.22            17.79  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   26.28                 25.65
# 2                     22.69                   41.52                 41.27
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                36.06          0.00                       3.0
# 2                46.80          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       2.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.01              4.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.03              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2019 = data_2019[data_2019["STATE"].isin(allowed_states)]
print(data_2019["STATE"].unique())

print(len(data_2019["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2019.isna().sum().sum()

# get location of each missing value
missing_locations = data_2019.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2019.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2019.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print(data_2019.iloc[68]["STATE"])
print(data_2019.iloc[68]["COUNTY"])
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Filled 6 missing values with 'NA'.
# Alaska
# Aleutians West Census Area

# %%
# repeat for 2018 data 
data_2018 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2018',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2018.head()
# Out:
#      YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2018.0  Alabama  Autauga County  South         55200.0
# 1  2018.0  Alabama  Baldwin County  South        208107.0
# 2  2018.0  Alabama  Barbour County  South         25782.0
# 3  2018.0  Alabama     Bibb County  South         22527.0
# 4  2018.0  Alabama   Blount County  South         57645.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54509.0                  2.0                2.20
# 1               206023.0                  3.0                6.21
# 2                25469.0                  6.0                5.89
# 3                22112.0                  1.0                9.24
# 4                57144.0                  1.0               10.46
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.33            18.07  ...                       5.40
# 1              6.51            18.61  ...                       7.50
# 2              8.58            22.69  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             10.22            17.79  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   26.28                 25.65
# 2                     22.69                   41.52                 41.27
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                36.06          0.00                       3.0
# 2                46.80          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       2.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.01              4.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.03              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2018 = data_2018[data_2018["STATE"].isin(allowed_states)]
print(data_2018["STATE"].unique())

print(len(data_2018["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2018.isna().sum().sum()

# get location of each missing value
missing_locations = data_2018.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2018.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2018.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print(data_2018.iloc[68]["STATE"])
print(data_2018.iloc[68]["COUNTY"])
print(data_2018.iloc[1815]["STATE"])
print(data_2018.iloc[1815]["COUNTY"])
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 1815, column 'ACS_TOT_POP_US_ABOVE1'
# Filled 7 missing values with 'NA'.
# Alaska
# Aleutians West Census Area
# New Mexico
# Rio Arriba County

# %%
# repeat for 2017 data 

data_2017 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2017',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2017.head()
# Out:
#      YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2017.0  Alabama  Autauga County  South         55036.0
# 1  2017.0  Alabama  Baldwin County  South        203360.0
# 2  2017.0  Alabama  Barbour County  South         26201.0
# 3  2017.0  Alabama     Bibb County  South         22580.0
# 4  2017.0  Alabama   Blount County  South         57667.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54293.0                  2.0                2.20
# 1               201089.0                  3.0                7.62
# 2                25925.0                  6.0                5.89
# 3                22224.0                  1.0                9.24
# 4                57088.0                  1.0               10.46
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.33            18.07  ...                       5.40
# 1              7.49            18.61  ...                       7.50
# 2              8.58            22.69  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             10.22            17.79  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   26.28                 25.65
# 2                     22.69                   41.52                 41.27
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                36.06          0.00                       3.0
# 2                46.80          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       2.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.01              3.0              0.01
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.03              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2017 = data_2017[data_2017["STATE"].isin(allowed_states)]
print(data_2017["STATE"].unique())

print(len(data_2017["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2017.isna().sum().sum()

# get location of each missing value
missing_locations = data_2017.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2017.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2017.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print(data_2017.iloc[68]["STATE"])
print(data_2017.iloc[68]["COUNTY"])
print(data_2017.iloc[85]["STATE"])
print(data_2017.iloc[85]["COUNTY"])
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 85, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 85, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 85, column 'POS_MAX_DIST_TRAUMA'
# Filled 9 missing values with 'NA'.
# Alaska
# Aleutians West Census Area
# Alaska
# North Slope Borough

# %%
# repeat for 2016 data 

data_2016 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2016',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2016.head()
# Out:
#      YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2016.0  Alabama  Autauga County  South         55049.0
# 1  2016.0  Alabama  Baldwin County  South        199510.0
# 2  2016.0  Alabama  Barbour County  South         26614.0
# 3  2016.0  Alabama     Bibb County  South         22572.0
# 4  2016.0  Alabama   Blount County  South         57704.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54311.0                  2.0                2.20
# 1               197124.0                  3.0                7.62
# 2                26332.0                  6.0                5.89
# 3                22349.0                  1.0                9.24
# 4                57199.0                  1.0               10.46
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.33            18.07  ...                       5.40
# 1              7.49            18.61  ...                       7.50
# 2              8.58            22.69  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             10.22            17.79  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   26.28                 25.65
# 2                     22.69                   43.95                 45.47
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                36.06          0.01                       3.0
# 2                53.56          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       2.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.02              3.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.03              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2016 = data_2016[data_2016["STATE"].isin(allowed_states)]
print(data_2016["STATE"].unique())

print(len(data_2016["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2016.isna().sum().sum()

# get location of each missing value
missing_locations = data_2016.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2016.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2016.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print((data_2016.iloc[68]["STATE"]), (data_2016.iloc[68]["COUNTY"]))
print((data_2016.iloc[85]["STATE"]), (data_2016.iloc[85]["COUNTY"]))
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 85, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 85, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 85, column 'POS_MAX_DIST_TRAUMA'
# Filled 9 missing values with 'NA'.
# Alaska Aleutians West Census Area
# Alaska North Slope Borough

# %%
# repeat for 2015 data 

data_2015 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2015',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2015.head()
# Out:
#    YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2015  Alabama  Autauga County  South         55221.0
# 1  2015  Alabama  Baldwin County  South        195121.0
# 2  2015  Alabama  Barbour County  South         26932.0
# 3  2015  Alabama     Bibb County  South         22604.0
# 4  2015  Alabama   Blount County  South         57710.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54662.0                  2.0                2.20
# 1               192790.0                  3.0                7.62
# 2                26692.0                  6.0                5.89
# 3                22359.0                  1.0                9.24
# 4                57157.0                  1.0               10.46
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.33            18.07  ...                       5.40
# 1              7.49            18.61  ...                       7.50
# 2              8.58            22.69  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             10.22            17.79  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   26.28                 25.65
# 2                     22.69                   43.95                 45.47
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                36.06          0.01                       3.0
# 2                53.56          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       2.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.02              3.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.03              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2015 = data_2015[data_2015["STATE"].isin(allowed_states)]
print(data_2015["STATE"].unique())

print(len(data_2015["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2015.isna().sum().sum()

# get location of each missing value
missing_locations = data_2015.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2015.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2015.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print((data_2015.iloc[67]["STATE"]), (data_2015.iloc[67]["COUNTY"]))
print((data_2015.iloc[68]["STATE"]), (data_2016.iloc[68]["COUNTY"]))
print((data_2015.iloc[84]["STATE"]), (data_2016.iloc[84]["COUNTY"]))
print((data_2015.iloc[85]["STATE"]), (data_2016.iloc[85]["COUNTY"]))
print((data_2015.iloc[86]["STATE"]), (data_2016.iloc[86]["COUNTY"]))
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 67, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 84, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 84, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 84, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 85, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 85, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 85, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 86, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 86, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 86, column 'POS_MAX_DIST_TRAUMA'
# Filled 18 missing values with 'NA'.
# Alaska Aleutians East Borough
# Alaska Aleutians West Census Area
# Alaska Nome Census Area
# Alaska North Slope Borough
# Alaska Northwest Arctic Borough

# %%
# repeat for 2014 data 

data_2014 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2014',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2014.head()
# Out:
#      YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2014.0  Alabama  Autauga County  South         55136.0
# 1  2014.0  Alabama  Baldwin County  South        191205.0
# 2  2014.0  Alabama  Barbour County  South         27119.0
# 3  2014.0  Alabama     Bibb County  South         22653.0
# 4  2014.0  Alabama   Blount County  South         57645.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54712.0                  2.0                2.20
# 1               188664.0                  3.0                7.62
# 2                26834.0                  6.0                5.89
# 3                22446.0                  1.0                9.24
# 4                57022.0                  1.0               10.46
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.33            18.07  ...                       5.40
# 1              7.49            18.61  ...                       7.50
# 2              8.58            22.69  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             10.22            17.79  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   26.28                 25.65
# 2                     22.69                   43.95                 45.47
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                36.06          0.01                       3.0
# 2                53.56          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       1.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.02              3.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.02              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2014 = data_2014[data_2014["STATE"].isin(allowed_states)]
print(data_2014["STATE"].unique())

print(len(data_2014["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2014.isna().sum().sum()

# get location of each missing value
missing_locations = data_2014.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2014.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2014.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print((data_2014.iloc[67]["STATE"]), (data_2014.iloc[67]["COUNTY"]))
print((data_2014.iloc[68]["STATE"]), (data_2014.iloc[68]["COUNTY"]))
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 67, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Filled 9 missing values with 'NA'.
# Alaska Aleutians East Borough
# Alaska Aleutians West Census Area

# %%
# repeat for 2013 data 

data_2013 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2013',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2013.head()
# Out:
#    YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2013  Alabama  Autauga County  South         54907.0
# 1  2013  Alabama  Baldwin County  South        187114.0
# 2  2013  Alabama  Barbour County  South         27321.0
# 3  2013  Alabama     Bibb County  South         22754.0
# 4  2013  Alabama   Blount County  South         57623.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54567.0                  2.0                2.20
# 1               184905.0                  3.0                7.62
# 2                27021.0                  6.0                5.89
# 3                22557.0                  1.0                9.24
# 4                56983.0                  1.0               10.46
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.33            18.07  ...                       5.40
# 1              7.49            18.61  ...                       7.50
# 2              8.58            22.69  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             10.22            17.79  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   26.28                 25.65
# 2                     22.69                   43.95                 45.47
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                36.06          0.01                       3.0
# 2                53.56          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       1.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.02              3.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.02              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2013 = data_2013[data_2013["STATE"].isin(allowed_states)]
print(data_2013["STATE"].unique())

print(len(data_2013["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2013.isna().sum().sum()

# get location of each missing value
missing_locations = data_2013.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2013.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2013.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print((data_2013.iloc[67]["STATE"]), (data_2013.iloc[67]["COUNTY"]))
print((data_2013.iloc[68]["STATE"]), (data_2013.iloc[68]["COUNTY"]))
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 67, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Filled 9 missing values with 'NA'.
# Alaska Aleutians East Borough
# Alaska Aleutians West Census Area

# %%
# repeat for 2012 data 

data_2012 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2012',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2012.head()
# Out:
#    YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2012  Alabama  Autauga County  South         54590.0
# 1  2012  Alabama  Baldwin County  South        183226.0
# 2  2012  Alabama  Barbour County  South         27469.0
# 3  2012  Alabama     Bibb County  South         22769.0
# 4  2012  Alabama   Blount County  South         57466.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54197.0                  2.0                2.20
# 1               180928.0                  3.0                7.62
# 2                27113.0                  6.0                5.89
# 3                22570.0                  1.0                9.24
# 4                56897.0                  1.0               10.46
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.33            18.07  ...                       5.40
# 1              7.49            18.61  ...                       7.50
# 2              8.58            22.69  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             10.22            17.79  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   26.28                 25.65
# 2                     22.69                   43.95                 45.47
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                36.06          0.01                       3.0
# 2                53.56          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       1.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.02              3.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.02              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2012 = data_2012[data_2012["STATE"].isin(allowed_states)]
print(data_2012["STATE"].unique())

print(len(data_2012["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2012.isna().sum().sum()

# get location of each missing value
missing_locations = data_2012.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2012.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2012.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print((data_2012.iloc[67]["STATE"]), (data_2012.iloc[67]["COUNTY"]))
print((data_2012.iloc[68]["STATE"]), (data_2012.iloc[68]["COUNTY"]))
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 67, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Filled 9 missing values with 'NA'.
# Alaska Aleutians East Borough
# Alaska Aleutians West Census Area

# %%
# repeat for 2011 data 

data_2011 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2011',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2011.head()
# Out:
#    YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2011  Alabama  Autauga County  South         53944.0
# 1  2011  Alabama  Baldwin County  South        179523.0
# 2  2011  Alabama  Barbour County  South         27546.0
# 3  2011  Alabama     Bibb County  South         22746.0
# 4  2011  Alabama   Blount County  South         57140.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                53436.0                  2.0                2.20
# 1               177221.0                  3.0                7.62
# 2                27117.0                  6.0                5.89
# 3                22600.0                  1.0                9.24
# 4                56552.0                  1.0               10.46
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.33            18.07  ...                       5.40
# 1              7.49            18.61  ...                       7.50
# 2              8.58            22.69  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             10.22            17.79  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   20.95                 20.69
# 2                     22.69                   43.95                 47.74
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                35.46          0.01                       3.0
# 2                63.22          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       1.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.02              3.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.02              1.0              0.02
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2011 = data_2011[data_2011["STATE"].isin(allowed_states)]
print(data_2011["STATE"].unique())

print(len(data_2011["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2011.isna().sum().sum()

# get location of each missing value
missing_locations = data_2011.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2011.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2011.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print((data_2011.iloc[67]["STATE"]), (data_2011.iloc[67]["COUNTY"]))
print((data_2011.iloc[68]["STATE"]), (data_2011.iloc[68]["COUNTY"]))
print((data_2011.iloc[69]["STATE"]), (data_2011.iloc[69]["COUNTY"]))
print((data_2011.iloc[74]["STATE"]), (data_2011.iloc[74]["COUNTY"]))
print((data_2011.iloc[78]["STATE"]), (data_2011.iloc[78]["COUNTY"]))
print((data_2011.iloc[80]["STATE"]), (data_2011.iloc[80]["COUNTY"]))
print((data_2011.iloc[81]["STATE"]), (data_2011.iloc[81]["COUNTY"]))
print((data_2011.iloc[90]["STATE"]), (data_2011.iloc[90]["COUNTY"]))
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 67, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 69, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 69, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 69, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 74, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 74, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 74, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 78, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 78, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 78, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 80, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 80, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 80, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 81, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 81, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 81, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 90, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 90, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 90, column 'POS_MAX_DIST_TRAUMA'
# Filled 27 missing values with 'NA'.
# Alaska Aleutians East Borough
# Alaska Aleutians West Census Area
# Alaska Anchorage Municipality
# Alaska Fairbanks North Star Borough
# Alaska Kenai Peninsula Borough
# Alaska Kodiak Island Borough
# Alaska Lake and Peninsula Borough
# Alaska Southeast Fairbanks Census Area

# %%
# repeat for 2010 data 

data_2010 = pd.read_excel("raw_data.xlsx", 
                          sheet_name= '2010',
                          usecols= ['STATE', 'YEAR', 'REGION', 'COUNTY', 'ACS_TOT_POP_WT','AHRF_USDA_RUCC_2013', 'ACS_TOT_POP_US_ABOVE1','POS_MEDIAN_DIST_ED', 'POS_MEAN_DIST_ED','POS_MAX_DIST_ED', 'POS_MEDIAN_DIST_MEDSURG_ICU', 'POS_MEAN_DIST_MEDSURG_ICU', 'POS_MAX_DIST_MEDSURG_ICU', 'POS_MEDIAN_DIST_TRAUMA', 'POS_MEAN_DIST_TRAUMA', 'POS_MAX_DIST_TRAUMA', 'POS_ASC_RATE', 'POS_TOT_HOSP_MEDSURG_ICU', 'POS_HOSP_MEDSURG_ICU_RATE', 'POS_TOT_HOSP_ED','POS_HOSP_ED_RATE'])
data_2010.head()
# Out:
#    YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2010  Alabama  Autauga County  South         53155.0
# 1  2010  Alabama  Baldwin County  South        175791.0
# 2  2010  Alabama  Barbour County  South         27699.0
# 3  2010  Alabama     Bibb County  South         22610.0
# 4  2010  Alabama   Blount County  South         56692.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                52568.0                  2.0               13.19
# 1               173522.0                  3.0               10.68
# 2                27230.0                  6.0               23.10
# 3                22449.0                  1.0                9.24
# 4                56071.0                  1.0               19.97
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0             14.38            25.09  ...                       5.40
# 1             10.90            23.31  ...                       7.50
# 2             22.73            25.34  ...                       8.58
# 3              8.97            15.08  ...                      21.39
# 4             20.94            25.61  ...                      10.46
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.99                   12.29                 14.95
# 1                     18.61                   20.95                 20.69
# 2                     22.69                   43.95                 47.74
# 3                     26.37                   25.09                 26.33
# 4                     19.91                   26.69                 27.71
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.38          0.02                       1.0
# 1                35.46          0.01                       3.0
# 2                63.22          0.00                       1.0
# 3                33.91          0.00                       0.0
# 4                35.86          0.00                       1.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              0.0              0.00
# 1                       0.02              2.0              0.01
# 2                       0.04              0.0              0.00
# 3                       0.00              1.0              0.04
# 4                       0.02              0.0              0.00
#
# [5 rows x 21 columns]

# %%
# drop columns that are not the 50 states
data_2010 = data_2010[data_2010["STATE"].isin(allowed_states)]
print(data_2010["STATE"].unique())

print(len(data_2010["STATE"].unique()))

# Count how many missing values exist before filling
missing_count = data_2010.isna().sum().sum()

# get location of each missing value
missing_locations = data_2010.isna()
rows, cols = np.where(missing_locations)
for r, c in zip(rows, cols):
    print(f"Missing value at row {r}, column '{data_2010.columns[c]}'")

# Fill all missing values with "NA"
data1 = data_2010.fillna("NA")

print(f"Filled {missing_count} missing values with 'NA'.")

print((data_2010.iloc[67]["STATE"]), (data_2010.iloc[67]["COUNTY"]))
print((data_2010.iloc[68]["STATE"]), (data_2010.iloc[68]["COUNTY"]))
print((data_2010.iloc[69]["STATE"]), (data_2010.iloc[69]["COUNTY"]))
print((data_2010.iloc[74]["STATE"]), (data_2010.iloc[74]["COUNTY"]))
print((data_2010.iloc[78]["STATE"]), (data_2010.iloc[78]["COUNTY"]))
print((data_2010.iloc[80]["STATE"]), (data_2010.iloc[80]["COUNTY"]))
print((data_2010.iloc[81]["STATE"]), (data_2010.iloc[81]["COUNTY"]))
print((data_2010.iloc[90]["STATE"]), (data_2010.iloc[90]["COUNTY"]))
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']
# 50
# Missing value at row 67, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 67, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEDIAN_DIST_ED'
# Missing value at row 68, column 'POS_MEAN_DIST_ED'
# Missing value at row 68, column 'POS_MAX_DIST_ED'
# Missing value at row 68, column 'POS_MEDIAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEAN_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MAX_DIST_MEDSURG_ICU'
# Missing value at row 68, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 68, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 69, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 69, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 69, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 74, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 74, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 74, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 78, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 78, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 78, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 80, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 80, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 80, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 81, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 81, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 81, column 'POS_MAX_DIST_TRAUMA'
# Missing value at row 90, column 'POS_MEDIAN_DIST_TRAUMA'
# Missing value at row 90, column 'POS_MEAN_DIST_TRAUMA'
# Missing value at row 90, column 'POS_MAX_DIST_TRAUMA'
# Filled 30 missing values with 'NA'.
# Alaska Aleutians East Borough
# Alaska Aleutians West Census Area
# Alaska Anchorage Municipality
# Alaska Fairbanks North Star Borough
# Alaska Kenai Peninsula Borough
# Alaska Kodiak Island Borough
# Alaska Lake and Peninsula Borough
# Alaska Southeast Fairbanks Census Area

# %%
# summary stats of total number, maxiumum, mean, medium distance to er, trauma, and icu; total number of ambulatory surgery centers

# %%
# mak eone big dataframe 

df_cleaned = pd.concat([data_2020, data_2019, data_2018, data_2017, data_2016, data_2015, data_2014, data_2013, data_2012, data_2011, data_2010], ignore_index=True)

df_cleaned['YEAR'] = df_cleaned['YEAR'].astype('Int64')
df_cleaned['AHRF_USDA_RUCC_2013'] = df_cleaned['AHRF_USDA_RUCC_2013'].astype('Int64')

df_cleaned.head()
# Out:
#    YEAR    STATE          COUNTY REGION  ACS_TOT_POP_WT  \
# 0  2020  Alabama  Autauga County  South         55639.0
# 1  2020  Alabama  Baldwin County  South        218289.0
# 2  2020  Alabama  Barbour County  South         25026.0
# 3  2020  Alabama     Bibb County  South         22374.0
# 4  2020  Alabama   Blount County  South         57755.0
#
#    ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 0                54929.0                    2                2.25
# 1               216518.0                    3                6.01
# 2                24792.0                    6                5.58
# 3                22073.0                    1                8.44
# 4                57164.0                    1               10.56
#
#    POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 0              5.29            17.88  ...                       5.36
# 1              6.44            13.43  ...                       7.52
# 2              8.56            22.72  ...                       8.56
# 3              8.34            15.53  ...                      21.31
# 4              9.68            17.69  ...                       9.82
#
#    POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 0                     18.95                   12.07                 14.68
# 1                     13.43                   25.37                 25.06
# 2                     22.72                   41.37                 41.32
# 3                     27.58                   26.40                 27.00
# 4                     19.89                   26.16                 27.23
#
#    POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 0                29.36          0.02                       1.0
# 1                36.79          0.00                       3.0
# 2                46.80          0.00                       1.0
# 3                35.98          0.00                       0.0
# 4                34.04          0.00                       2.0
#
#    POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 0                       0.02              1.0              0.02
# 1                       0.01              4.0              0.02
# 2                       0.04              1.0              0.04
# 3                       0.00              1.0              0.04
# 4                       0.03              1.0              0.02
#
# [5 rows x 21 columns]

# %%
df_cleaned[df_cleaned['AHRF_USDA_RUCC_2013'].isna()]
# Out:
#     YEAR   STATE                    COUNTY REGION  ACS_TOT_POP_WT  \
# 72  2020  Alaska       Chugach Census Area   West          6495.0
# 73  2020  Alaska  Copper River Census Area   West          2894.0
#
#     ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  \
# 72                 6453.0                 <NA>                3.44
# 73                 2835.0                 <NA>               16.63
#
#     POS_MEAN_DIST_ED  POS_MAX_DIST_ED  ...  POS_MEAN_DIST_MEDSURG_ICU  \
# 72              3.44             5.89  ...                     114.39
# 73             16.63            16.63  ...                     142.15
#
#     POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  \
# 72                    130.92                   24.45                 24.45
# 73                    142.15                   78.58                 78.58
#
#     POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  \
# 72                42.54           0.0                       0.0
# 73                78.58           0.0                       0.0
#
#     POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# 72                        0.0              4.0              0.62
# 73                        0.0              1.0              0.35
#
# [2 rows x 21 columns]

# %%
df_cleaned['AHRF_USDA_RUCC_2013'].describe()
# Out:
# count     34555.0
# mean     5.009521
# std      2.707542
# min           1.0
# 25%           2.0
# 50%           6.0
# 75%           7.0
# max           9.0
# Name: AHRF_USDA_RUCC_2013, dtype: Float64

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 2000)

# %%
df_cleaned.describe()
# Out:
#               YEAR  ACS_TOT_POP_WT  ACS_TOT_POP_US_ABOVE1  AHRF_USDA_RUCC_2013  POS_MEDIAN_DIST_ED  POS_MEAN_DIST_ED  POS_MAX_DIST_ED  POS_MEDIAN_DIST_MEDSURG_ICU  POS_MEAN_DIST_MEDSURG_ICU  POS_MAX_DIST_MEDSURG_ICU  POS_MEDIAN_DIST_TRAUMA  POS_MEAN_DIST_TRAUMA  POS_MAX_DIST_TRAUMA  POS_ASC_RATE  POS_TOT_HOSP_MEDSURG_ICU  POS_HOSP_MEDSURG_ICU_RATE  POS_TOT_HOSP_ED  POS_HOSP_ED_RATE
# count      34557.0    3.455600e+04           3.455500e+04              34555.0        34555.000000      34555.000000     34555.000000                 34545.000000               34545.000000              34545.000000            34522.000000          34522.000000         34522.000000  34557.000000              34557.000000               34557.000000     34557.000000      34557.000000
# mean   2015.090806    1.004424e+05           9.925256e+04             5.009521            8.277849          8.750434        15.643360                    12.201709                  12.677978                 19.806021               24.277468             24.518800            32.224534      0.011250                  1.853951                   0.038692         2.455913          0.094210
# std       3.088477    3.219663e+05           3.180109e+05             2.707542           14.071116         13.775010        15.123102                    18.533523                  18.234119                 18.874719               25.134059             24.906422            25.625092      0.022771                  5.061521                   0.074129         4.828492          0.165345
# min         2010.0    4.100000e+01           4.100000e+01                  1.0            0.130000          0.130000         0.130000                     0.130000                   0.130000                  0.130000                0.130000              0.130000             0.130000      0.000000                  0.000000                   0.000000         0.000000          0.000000
# 25%         2013.0    1.101250e+04           1.089350e+04                  2.0            2.940000          4.070000         9.830000                     3.450000                   4.650000                 11.660000                7.690000              8.160000            18.630000      0.000000                  0.000000                   0.000000         1.000000          0.010000
# 50%         2015.0    2.573900e+04           2.546200e+04                  6.0            5.280000          5.890000        13.340000                     6.900000                   7.320000                 16.170000               20.330000             20.380000            27.510000      0.000000                  1.000000                   0.020000         2.000000          0.040000
# 75%         2018.0    6.708300e+04           6.638950e+04                  7.0            9.270000          9.150000        17.955000                    16.720000                  16.620000                 23.260000               33.040000             33.000000            40.330000      0.020000                  2.000000                   0.040000         3.000000          0.110000
# max         2020.0    1.010572e+07           9.988370e+06                  9.0          468.840000        468.840000       468.840000                   487.030000                 487.030000                487.030000              497.220000            497.220000           497.220000      0.430000                177.000000                   1.120000       147.000000          2.770000

# %%
df_cleaned.groupby('AHRF_USDA_RUCC_2013').describe()
# Out:
#                        YEAR                                                                ACS_TOT_POP_WT                                                                                   ACS_TOT_POP_US_ABOVE1                                                                                  POS_MEDIAN_DIST_ED                                                            POS_MEAN_DIST_ED                                                             POS_MAX_DIST_ED                                                            POS_MEDIAN_DIST_MEDSURG_ICU                                                              POS_MEAN_DIST_MEDSURG_ICU                                                          POS_MAX_DIST_MEDSURG_ICU                                                              POS_MEDIAN_DIST_TRAUMA                                                              POS_MEAN_DIST_TRAUMA                                                             POS_MAX_DIST_TRAUMA                                                              POS_ASC_RATE                                                  POS_TOT_HOSP_MEDSURG_ICU                                                 POS_HOSP_MEDSURG_ICU_RATE                                                  POS_TOT_HOSP_ED                                                 POS_HOSP_ED_RATE
#                       count         mean       std     min     25%     50%     75%     max          count           mean            std      min       25%       50%        75%         max                 count           mean            std      min       25%       50%        75%        max              count       mean        std   min   25%     50%      75%     max            count       mean        std   min     25%    50%      75%     max           count       mean        std   min      25%    50%    75%     max                       count       mean        std   min      25%    50%      75%     max                     count       mean        std   min    25%    50%    75%     max                    count       mean        std   min     25%     50%      75%     max                  count       mean        std   min      25%    50%      75%     max                count       mean        std   min    25%     50%      75%     max               count       mean        std   min      25%     50%     75%     max        count      mean       std  min   25%   50%   75%   max                    count      mean        std  min  25%  50%  75%    max                     count      mean       std  min   25%   50%   75%   max           count      mean        std  min  25%  50%  75%    max            count      mean       std  min   25%   50%   75%   max
# AHRF_USDA_RUCC_2013
# 1                    4741.0  2015.090909   3.08856  2010.0  2013.0  2015.0  2018.0  2020.0         4741.0  402242.406876  769776.954817   4782.0  43169.00  138148.0  491307.00  10105722.0                4741.0  397406.893904  760278.366231   4763.0  42770.00  136589.0  485610.00  9988370.0             4741.0   5.728758   4.612006  0.47  2.60   4.320   7.1200   51.62           4741.0   5.991278   4.377322  0.55  3.2100  4.850   7.0700   50.48          4741.0  13.436351   7.008240  0.70   9.4700  12.58  15.74   80.95                      4741.0   6.158403   5.084114  0.52   2.6400   4.39   7.5600   27.03                    4741.0   6.498416   4.925749  0.58   3.26   4.88   7.68   26.69                   4741.0  14.045115   7.101244  1.80   9.740  12.930  16.5600   71.65                 4741.0  14.267167  10.156248  0.58   5.4400  12.33  20.5000   49.84               4741.0  14.568743   9.942953  0.58   6.39  12.860  20.7900   48.79              4741.0  24.385571  11.812771  0.70  16.4100  23.310  30.540  126.88       4741.0  0.017505  0.021853  0.0  0.00  0.01  0.03  0.16                   4741.0  5.544400  12.381437  0.0  1.0  2.0  5.0  177.0                    4741.0  0.014518  0.014691  0.0  0.00  0.01  0.02  0.10          4741.0  5.741405  11.540837  0.0  1.0  2.0  5.0  147.0           4741.0  0.021386  0.030037  0.0  0.01  0.01  0.02  0.38
# 2                    4162.0  2015.087698  3.089119  2010.0  2013.0  2015.0  2018.0  2020.0         4162.0  177713.636953  196363.576169   1773.0  34722.00   93102.5  272293.50   1038476.0                4162.0  175581.911821  193904.756596   1768.0  34400.75   92005.5  269604.00  1028084.0             4162.0   6.299198   5.697620  1.00  2.72   4.580   7.6025   87.59           4162.0   6.952086   5.401557  1.00  3.7825  5.290   7.9100   86.49          4162.0  15.975690   7.770647  1.00  11.4300  14.44  18.23   91.75                      4162.0   7.544298   6.821726  1.00   2.8000   4.79   9.7900   51.52                    4162.0   8.217126   6.425292  1.00   4.09   5.54   9.94   51.52                   4162.0  17.748945   8.616707  1.00  12.070  15.710  21.6600   75.77                 4160.0  14.656584  16.116839  1.46   4.8600  11.93  20.5225  490.63               4160.0  15.289341  15.843507  2.15   6.02  12.700  20.4500  490.63              4160.0  26.489993  16.902409  4.93  17.8600  24.200  30.850  490.63       4162.0  0.015985  0.020629  0.0  0.00  0.01  0.03  0.13                   4162.0  2.669630   3.073119  0.0  0.0  2.0  4.0   18.0                    4162.0  0.016492  0.020069  0.0  0.00  0.01  0.02  0.26          4162.0  3.266699   3.535991  0.0  1.0  2.0  4.0   26.0           4162.0  0.030634  0.042185  0.0  0.01  0.02  0.03  0.35
# 3                    3916.0  2015.090909  3.088629  2010.0  2013.0  2015.0  2018.0  2020.0         3916.0   80836.168539   61947.222418     57.0  20279.00   75845.0  126766.00    250649.0                3916.0   79886.953779   61211.185210     57.0  19999.25   74911.0  125217.50   247525.0             3916.0   6.512135   6.003521  0.81  2.59   3.930   8.1400   54.72           3916.0   7.290207   5.557132  0.81  3.8300  5.230   8.5000   52.73          3916.0  15.722214   7.618708  0.81  11.0100  14.09  18.45   69.79                      3916.0   7.609803   7.216829  0.75   2.6900   4.06  10.8675   51.92                    3916.0   8.488067   6.737648  0.79   4.00   5.54  11.53   51.92                   3916.0  17.612796   8.597628  1.69  12.060  15.710  21.3400   71.03                 3914.0  20.399954  20.770452  0.81   4.2525  16.93  29.6700  378.96               3914.0  20.891456  20.279442  0.81   6.00  17.070  29.6700  378.38              3914.0  30.233822  20.898558  0.81  17.6300  25.970  38.140  384.39       3916.0  0.022898  0.029846  0.0  0.00  0.01  0.04  0.18                   3916.0  1.688713   1.581465  0.0  0.0  1.0  2.0    9.0                    3916.0  0.022508  0.029727  0.0  0.00  0.02  0.03  0.26          3916.0  2.184116   1.927700  0.0  1.0  2.0  3.0   11.0           3916.0  0.040592  0.057179  0.0  0.01  0.02  0.04  0.50
# 4                    2354.0  2015.090909   3.08889  2010.0  2013.0  2015.0  2018.0  2020.0         2354.0   63291.776975   24376.216726  12646.0  45339.00   58579.5   76033.00    189916.0                2353.0   62603.394390   24145.166851  12446.0  44710.00   58070.0   75260.00   188279.0             2354.0   5.324269   4.943667  1.07  2.60   4.050   6.0000   59.94           2354.0   6.430017   4.569673  1.48  4.2325  5.270   6.8300   62.42          2354.0  15.766491   8.919447  2.65  10.9525  13.94  17.18  111.75                      2354.0   5.738127   5.592081  1.20   2.7100   4.25   6.7400   41.15                    2354.0   6.922566   5.954878  1.48   4.48   5.54   7.12   58.86                   2354.0  16.798755  11.026477  2.65  11.620  14.290  18.7125  104.31                 2354.0  23.675004  16.501284  1.35   9.0100  22.76  34.0000   90.79               2354.0  24.029533  15.915274  2.60   9.47  22.485  34.0675   84.50              2354.0  34.058700  19.031420  5.13  20.5700  30.250  43.050  151.48       2354.0  0.019524  0.023246  0.0  0.00  0.01  0.03  0.14                   2354.0  1.820731   1.233191  0.0  1.0  1.0  2.0    6.0                    2354.0  0.029830  0.018871  0.0  0.02  0.03  0.04  0.11          2354.0  2.193288   1.537608  0.0  1.0  2.0  3.0    9.0           2354.0  0.036321  0.024534  0.0  0.02  0.03  0.05  0.14
# 5                    1012.0  2015.090909  3.089761  2010.0  2013.0  2015.0  2018.0  2020.0         1012.0   54282.475296   24264.666196  21902.0  36755.25   48501.5   65459.25    201350.0                1012.0   53610.869565   23998.126462  21493.0  36323.50   47952.0   64626.75   198803.0             1012.0   4.966887   7.155095  0.96  2.31   3.040   5.0700  102.62           1012.0   6.473953   6.871082  1.60  3.8500  4.650   6.2300  102.41          1012.0  17.566215  13.242542  3.53  10.3700  14.16  19.26  111.39                      1012.0   4.049170   3.245846  0.96   2.3575   3.03   5.0700   52.98                    1012.0   5.841393   3.453831  1.60   3.89   5.02   6.20   53.40                   1012.0  18.136028  13.085099  3.53  10.730  14.870  19.5000   85.92                 1012.0  25.265128  24.809383  1.34   4.4050  19.59  37.6225  205.84               1012.0  25.657065  23.861460  2.04   6.02  19.960  38.3400  193.93              1012.0  35.732875  25.499994  3.84  16.3000  28.790  48.055  233.53       1012.0  0.032233  0.029077  0.0  0.01  0.03  0.05  0.17                   1012.0  1.791502   1.172132  0.0  1.0  1.0  2.0    7.0                    1012.0  0.035277  0.020305  0.0  0.02  0.03  0.04  0.12          1012.0  2.131423   1.647923  0.0  1.0  2.0  3.0    9.0           1012.0  0.040188  0.025220  0.0  0.02  0.03  0.06  0.12
# 6                    6523.0  2015.090909  3.088471  2010.0  2013.0  2015.0  2018.0  2020.0         6523.0   24778.342327   12655.587936   3298.0  14801.00   22690.0   32857.50     72346.0                6523.0   24505.719301   12522.384801   3274.0  14619.00   22435.0   32512.00    71356.0             6523.0   7.102879   5.710839  0.38  3.63   5.770   8.5450   66.25           6523.0   7.489519   5.259370  0.40  4.6500  6.090   8.4500   61.23          6523.0  14.019762   7.429760  0.40   9.6600  12.51  16.53   74.31                      6523.0  11.610799   9.644964  0.40   4.8700   8.30  16.3800   72.10                    6523.0  11.900339   9.235747  0.40   5.70   8.50  16.49   66.98                   6523.0  18.433859  10.097315  0.40  11.780  16.620  22.4950   74.57                 6523.0  25.225137  15.472858  0.61  12.6350  23.95  35.7900  126.20               6523.0  25.229166  15.057123  0.73  12.10  24.020  35.7950  120.09              6523.0  32.115891  15.890401  0.73  20.5900  30.300  42.680  130.84       6523.0  0.004398  0.015519  0.0  0.00  0.00  0.00  0.22                   6523.0  0.990035   0.922341  0.0  0.0  1.0  2.0    5.0                    6523.0  0.043126  0.047348  0.0  0.00  0.03  0.06  0.32          6523.0  1.837651   1.294616  0.0  1.0  2.0  2.0   10.0           6523.0  0.094496  0.084756  0.0  0.04  0.07  0.13  0.90
# 7                    4763.0  2015.090909  3.088558  2010.0  2013.0  2015.0  2018.0  2020.0         4763.0   18928.940164   11118.227384   3393.0  10126.00   16456.0   25271.50     72412.0                4763.0   18715.588075   10999.994653   3357.0   9979.50   16280.0   24936.50    71794.0             4763.0   7.075293   9.335093  0.25  2.60   5.000   8.0000  184.40           4763.0   7.801027   8.661188  0.28  4.0800  5.770   8.1500  184.40          4763.0  15.074304  13.879493  0.28   8.3900  12.47  17.49  199.36                      4763.0  14.166408  27.186245  0.38   3.4800   7.12  17.8300  390.88                    4763.0  14.763468  26.955565  0.41   5.11   7.92  17.57  390.88                   4763.0  21.934195  27.952267  0.41  10.780  16.320  25.2500  405.00                 4754.0  30.900141  34.504804  0.25   8.2600  24.35  42.8000  425.84               4754.0  31.108479  34.134895  0.28   9.23  23.990  42.4100  425.84              4754.0  38.007911  35.175710  0.28  18.1100  30.450  49.560  428.63       4763.0  0.007466  0.020988  0.0  0.00  0.00  0.00  0.18                   4763.0  1.097208   0.946489  0.0  0.0  1.0  2.0    5.0                    4763.0  0.069906  0.081168  0.0  0.00  0.05  0.10  0.51          4763.0  1.834348   1.175158  0.0  1.0  2.0  2.0    8.0           4763.0  0.131505  0.110672  0.0  0.05  0.10  0.19  0.67
# 8                    2420.0  2015.090909  3.088872  2010.0  2013.0  2015.0  2018.0  2020.0         2420.0    9706.646694    6312.137707    564.0   4803.00    8580.0   13333.50     36654.0                2420.0    9607.001653    6248.072633    564.0   4772.25    8489.0   13156.75    36298.0             2420.0  12.063930   9.184428  0.14  6.03  10.185  15.9900   77.18           2420.0  11.919744   9.092961  0.14  6.0700  9.860  15.5925   77.18          2420.0  15.144694   9.095196  0.14   9.5800  13.58  18.96   77.18                      2420.0  19.871934  11.460353  0.62  12.4300  18.62  24.6600   77.18                    2420.0  19.829731  11.434144  0.62  12.26  18.05  24.32   77.18                   2420.0  23.105744  11.095572  0.62  15.735  21.215  28.6200   77.18                 2420.0  27.373905  23.334934  0.14  15.5800  25.28  35.1800  490.23               2420.0  27.362223  23.385487  0.14  15.17  25.410  35.6125  490.23              2420.0  31.183901  23.611009  0.14  18.2550  29.220  40.680  490.23       2420.0  0.002723  0.029016  0.0  0.00  0.00  0.00  0.43                   2420.0  0.271901   0.600774  0.0  0.0  0.0  0.0    3.0                    2420.0  0.029690  0.072501  0.0  0.00  0.00  0.00  0.58          2420.0  1.053306   1.143691  0.0  0.0  1.0  2.0    5.0           2420.0  0.148202  0.214023  0.0  0.00  0.08  0.22  1.38
# 9                    4664.0  2015.090909  3.088565  2010.0  2013.0  2015.0  2018.0  2020.0         4663.0    6100.894703    5073.953423     41.0   2401.00    4788.0    8282.00     29462.0                4663.0    6035.930088    5025.514033     41.0   2376.00    4744.0    8206.50    29138.0             4662.0  17.236371  32.778083  0.13  4.26  10.110  20.8600  468.84           4662.0  17.142726  32.574525  0.13  4.7700  9.715  20.7000  468.84          4662.0  20.159101  33.425758  0.13   6.8500  14.68  23.09  468.84                      4652.0  26.214086  33.443268  0.13  11.4350  20.66  30.2400  487.03                    4652.0  26.078418  33.191264  0.13  11.01  20.27  30.02  487.03                   4652.0  29.227158  34.724532  0.13  15.540  23.140  32.7200  487.03                 4642.0  36.742632  38.466726  0.13  18.1300  29.35  45.6925  497.22               4642.0  36.769746  38.767948  0.13  18.07  29.350  45.8400  497.22              4642.0  40.113369  41.013096  0.13  21.1375  32.325  47.920  497.22       4664.0  0.000030  0.001449  0.0  0.00  0.00  0.00  0.07                   4664.0  0.346484   0.685952  0.0  0.0  0.0  0.0    5.0                    4664.0  0.068486  0.152620  0.0  0.00  0.00  0.00  1.12          4664.0  1.051029   1.133947  0.0  0.0  1.0  2.0    6.0           4664.0  0.244254  0.333655  0.0  0.00  0.11  0.39  2.77

# %%
for col in df_cleaned.columns:
    print(f"--- {col} ---")
    print(df_cleaned[col].describe())
    print()
# Out:
# --- YEAR ---
# count        34557.0
# mean     2015.090806
# std         3.088477
# min           2010.0
# 25%           2013.0
# 50%           2015.0
# 75%           2018.0
# max           2020.0
# Name: YEAR, dtype: Float64
#
# --- STATE ---
# count     34557
# unique       50
# top       Texas
# freq       2794
# Name: STATE, dtype: object
#
# --- COUNTY ---
# count                 34557
# unique                 1878
# top       Washington County
# freq                    341
# Name: COUNTY, dtype: object
#
# --- REGION ---
# count     34557
# unique        4
# top       South
# freq      15635
# Name: REGION, dtype: object
#
# --- ACS_TOT_POP_WT ---
# count    3.455600e+04
# mean     1.004424e+05
# std      3.219663e+05
# min      4.100000e+01
# 25%      1.101250e+04
# 50%      2.573900e+04
# 75%      6.708300e+04
# max      1.010572e+07
# Name: ACS_TOT_POP_WT, dtype: float64
#
# --- ACS_TOT_POP_US_ABOVE1 ---
# count    3.455500e+04
# mean     9.925256e+04
# std      3.180109e+05
# min      4.100000e+01
# 25%      1.089350e+04
# 50%      2.546200e+04
# 75%      6.638950e+04
# max      9.988370e+06
# Name: ACS_TOT_POP_US_ABOVE1, dtype: float64
#
# --- AHRF_USDA_RUCC_2013 ---
# count     34555.0
# mean     5.009521
# std      2.707542
# min           1.0
# 25%           2.0
# 50%           6.0
# 75%           7.0
# max           9.0
# Name: AHRF_USDA_RUCC_2013, dtype: Float64
#
# --- POS_MEDIAN_DIST_ED ---
# count    34555.000000
# mean         8.277849
# std         14.071116
# min          0.130000
# 25%          2.940000
# 50%          5.280000
# 75%          9.270000
# max        468.840000
# Name: POS_MEDIAN_DIST_ED, dtype: float64
#
# --- POS_MEAN_DIST_ED ---
# count    34555.000000
# mean         8.750434
# std         13.775010
# min          0.130000
# 25%          4.070000
# 50%          5.890000
# 75%          9.150000
# max        468.840000
# Name: POS_MEAN_DIST_ED, dtype: float64
#
# --- POS_MAX_DIST_ED ---
# count    34555.000000
# mean        15.643360
# std         15.123102
# min          0.130000
# 25%          9.830000
# 50%         13.340000
# 75%         17.955000
# max        468.840000
# Name: POS_MAX_DIST_ED, dtype: float64
#
# --- POS_MEDIAN_DIST_MEDSURG_ICU ---
# count    34545.000000
# mean        12.201709
# std         18.533523
# min          0.130000
# 25%          3.450000
# 50%          6.900000
# 75%         16.720000
# max        487.030000
# Name: POS_MEDIAN_DIST_MEDSURG_ICU, dtype: float64
#
# --- POS_MEAN_DIST_MEDSURG_ICU ---
# count    34545.000000
# mean        12.677978
# std         18.234119
# min          0.130000
# 25%          4.650000
# 50%          7.320000
# 75%         16.620000
# max        487.030000
# Name: POS_MEAN_DIST_MEDSURG_ICU, dtype: float64
#
# --- POS_MAX_DIST_MEDSURG_ICU ---
# count    34545.000000
# mean        19.806021
# std         18.874719
# min          0.130000
# 25%         11.660000
# 50%         16.170000
# 75%         23.260000
# max        487.030000
# Name: POS_MAX_DIST_MEDSURG_ICU, dtype: float64
#
# --- POS_MEDIAN_DIST_TRAUMA ---
# count    34522.000000
# mean        24.277468
# std         25.134059
# min          0.130000
# 25%          7.690000
# 50%         20.330000
# 75%         33.040000
# max        497.220000
# Name: POS_MEDIAN_DIST_TRAUMA, dtype: float64
#
# --- POS_MEAN_DIST_TRAUMA ---
# count    34522.000000
# mean        24.518800
# std         24.906422
# min          0.130000
# 25%          8.160000
# 50%         20.380000
# 75%         33.000000
# max        497.220000
# Name: POS_MEAN_DIST_TRAUMA, dtype: float64
#
# --- POS_MAX_DIST_TRAUMA ---
# count    34522.000000
# mean        32.224534
# std         25.625092
# min          0.130000
# 25%         18.630000
# 50%         27.510000
# 75%         40.330000
# max        497.220000
# Name: POS_MAX_DIST_TRAUMA, dtype: float64
#
# --- POS_ASC_RATE ---
# count    34557.000000
# mean         0.011250
# std          0.022771
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.020000
# max          0.430000
# Name: POS_ASC_RATE, dtype: float64
#
# --- POS_TOT_HOSP_MEDSURG_ICU ---
# count    34557.000000
# mean         1.853951
# std          5.061521
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max        177.000000
# Name: POS_TOT_HOSP_MEDSURG_ICU, dtype: float64
#
# --- POS_HOSP_MEDSURG_ICU_RATE ---
# count    34557.000000
# mean         0.038692
# std          0.074129
# min          0.000000
# 25%          0.000000
# 50%          0.020000
# 75%          0.040000
# max          1.120000
# Name: POS_HOSP_MEDSURG_ICU_RATE, dtype: float64
#
# --- POS_TOT_HOSP_ED ---
# count    34557.000000
# mean         2.455913
# std          4.828492
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max        147.000000
# Name: POS_TOT_HOSP_ED, dtype: float64
#
# --- POS_HOSP_ED_RATE ---
# count    34557.000000
# mean         0.094210
# std          0.165345
# min          0.000000
# 25%          0.010000
# 50%          0.040000
# 75%          0.110000
# max          2.770000
# Name: POS_HOSP_ED_RATE, dtype: float64

# %%
df_cleaned['AHRF_USDA_RUCC_2013'].describe()

# %%
df_cleaned.to_pickle("clean_data.pkl")
