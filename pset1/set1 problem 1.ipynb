# %%
# !pip install BeautifulSoup4
# !pip install lxml
import xml.etree.ElementTree as ET

# %%
tree = ET.parse(r"pset1-patients.xml")
root = tree.getroot()

# %%
#SOURCES 
# https://pythonguides.com/read-xml-files-in-python/ for parsing xml files
